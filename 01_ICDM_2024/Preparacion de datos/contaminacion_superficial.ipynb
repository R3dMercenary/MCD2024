# %%
import pandas as pd
import urllib

# %% [markdown]
# ## Configuraciones:

# %%
url="https://files.conagua.gob.mx/aguasnacionales/TODOS%20LOS%20MONITOREOS.xlsb"
estado="Sonora"

# %%
temp_file=urllib.request.urlretrieve(url)
# Out:
# ('/tmp/tmpdlxbioo9', <http.client.HTTPMessage at 0x7fed79e5ef50>)

# %%
df=pd.read_excel(temp_file)
df
# Out:
#        CLAVE SITIO                                   NOMBRE DEL SITIO  \
# 0        OCPYU4929                                            COSGAYA
# 1        OCPYU4946       POZO 1 DEL SISTEMA DE AGUA POTABLE DE SOTUTA
# 2      OCPYU4953W1                     ANILLO DE CENOTES DE YUCATAN 5
# 3        OCPYU6396                                          CACALCHEN
# 4        OCPYU6397                                          CANSAHCAB
# ...            ...                                                ...
# 7246  OCRBR0003RNL                       ENTRADA LAGUNA DE SALINILLAS
# 7247  OCRBR0004RNL                  CENTRO DE LA LAGUNA DE SALINILLAS
# 7248  OCRBR0006RNL  RIO LA SILLA DEBAJO DEL PUENTE TOLTECA  (AGUAS...
# 7249  OCRBR0007RNL          RIO LA SILLA   (A LA ALTURA DEL COLECTOR)
# 7250  OCRBR0008RNL         RIO LA SILLA   (AGUAS ARRIBA DEL COLECTOR)
#
#             CUENCA  CLAVE ACUÍFERO              ACUÍFERO  \
# 0              NaN          3105.0  PENÍNSULA DE YUCATÁN
# 1              NaN          3105.0  PENÍNSULA DE YUCATÁN
# 2              NaN          3105.0  PENÍNSULA DE YUCATÁN
# 3              NaN          3105.0  PENÍNSULA DE YUCATÁN
# 4              NaN          3105.0  PENÍNSULA DE YUCATÁN
# ...            ...             ...                   ...
# 7246    RIO SALADO             NaN                   NaN
# 7247    RIO SALADO             NaN                   NaN
# 7248  RIO SAN JUAN             NaN                   NaN
# 7249  RIO SAN JUAN             NaN                   NaN
# 7250  RIO SAN JUAN             NaN                   NaN
#
#           ORGANISMO CUENCA DIRECCIÓN LOCAL      ESTADO  MUNICIPIO  \
# 0     PENÍNSULA DE YUCATÁN             NaN     YUCATÁN     MÉRIDA
# 1     PENÍNSULA DE YUCATÁN             NaN     YUCATÁN     SOTUTA
# 2     PENÍNSULA DE YUCATÁN             NaN     YUCATÁN     KOPOMÁ
# 3     PENÍNSULA DE YUCATÁN             NaN     YUCATÁN  CACALCHEN
# 4     PENÍNSULA DE YUCATÁN             NaN     YUCATÁN  CANSAHCAB
# ...                    ...             ...         ...        ...
# 7246             RÍO BRAVO             NaN  NUEVO LEÓN    ANAHUAC
# 7247             RÍO BRAVO             NaN  NUEVO LEÓN    ANAHUAC
# 7248             RÍO BRAVO             NaN  NUEVO LEÓN  GUADALUPE
# 7249             RÍO BRAVO             NaN  NUEVO LEÓN  GUADALUPE
# 7250             RÍO BRAVO             NaN  NUEVO LEÓN  GUADALUPE
#
#                      CUERPO DE AGUA          TIPO DE CUERPO DE AGUA  \
# 0     ACUÍFERO PENÍNSULA DE YUCATÁN  SUBTERRÁNEO (ESTUDIO ESPECIAL)
# 1     ACUÍFERO PENÍNSULA DE YUCATÁN  SUBTERRÁNEO (ESTUDIO ESPECIAL)
# 2     ACUÍFERO PENÍNSULA DE YUCATÁN  SUBTERRÁNEO (ESTUDIO ESPECIAL)
# 3     ACUÍFERO PENINSULA DE YUCATAN  SUBTERRÁNEO (ESTUDIO ESPECIAL)
# 4     ACUÍFERO PENINSULA DE YUCATAN  SUBTERRÁNEO (ESTUDIO ESPECIAL)
# ...                             ...                             ...
# 7246           LAGUNA DE SALINILLAS                         LÉNTICO
# 7247           LAGUNA DE SALINILLAS                         LÉNTICO
# 7248                   RIO LA SILLA                          LÓTICO
# 7249                   RIO LA SILLA                          LÓTICO
# 7250                   RIO LA SILLA                          LÓTICO
#
#      SUBTIPO CUERPO AGUA    LATITUD    LONGITUD
# 0                   POZO  21.096990  -89.704600
# 1                   POZO  20.597040  -89.007570
# 2                 CENOTE  20.689430  -89.876050
# 3                   POZO  20.982222  -89.227778
# 4                   POZO  21.156850  -89.089960
# ...                  ...        ...         ...
# 7246              LAGUNA  27.439458 -100.399600
# 7247              LAGUNA  27.438647 -100.391253
# 7248                 RIO  26.675143 -100.237204
# 7249                 RIO  26.674166 -100.241170
# 7250                 RIO  26.671869 -100.245895
#
# [7251 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7251 entries, 0 to 7250
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLAVE SITIO             7251 non-null   object
#  1   NOMBRE DEL SITIO        7251 non-null   object
#  2   CUENCA                  4625 non-null   object
#  3   CLAVE ACUÍFERO          2623 non-null   float64
#  4   ACUÍFERO                2623 non-null   object
#  5   ORGANISMO CUENCA        7251 non-null   object
#  6   DIRECCIÓN LOCAL         3543 non-null   object
#  7   ESTADO                  7251 non-null   object
#  8   MUNICIPIO               7251 non-null   object
#  9   CUERPO DE AGUA          7245 non-null   object
#  10  TIPO DE CUERPO DE AGUA  7251 non-null   object
#  11  SUBTIPO CUERPO AGUA     7251 non-null   object
#  12  LATITUD                 7251 non-null   float64
#  13  LONGITUD                7251 non-null   float64
# dtypes: float64(3), object(11)
# memory usage: 793.2+ KB

# %%
file_2012_to_2023=urllib.request.urlretrieve("https://www.gob.mx/cms/uploads/attachment/file/936145/Calidad_del_Agua_Superficial_p.xlsx")
file_2023=urllib.request.urlretrieve("https://www.gob.mx/cms/uploads/attachment/file/936143/Calidad_del_Agua_Superficial_a.xlsx")
print(file_2012_to_2023)
print(file_2023)
# Out:
# ('/tmp/tmpcgw6rp0p', <http.client.HTTPMessage object at 0x7fdf33eefb20>)
# ('/tmp/tmpmwsaoyd7', <http.client.HTTPMessage object at 0x7fdf33eedf30>)

# %%
df_A=pd.read_excel(file_2023[0])
df_B=pd.read_excel(file_2012_to_2023[0])
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
df_A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLAVE                   450 non-null    object
#  1   SITIO                   450 non-null    object
#  2   ORGANISMO_DE_CUENCA     450 non-null    object
#  3   ESTADO                  450 non-null    object
#  4   MUNICIPIO               450 non-null    object
#  5   CUENCA                  448 non-null    object
#  6   CUERPO DE AGUA          450 non-null    object
#  7   TIPO                    450 non-null    object
#  8   SUBTIPO                 450 non-null    object
#  9   LONGITUD                450 non-null    float64
#  10  LATITUD                 450 non-null    float64
#  11  PERIODO                 450 non-null    int64
#  12  DBO_mg/L                370 non-null    object
#  13  CALIDAD_DBO             370 non-null    object
#  14  DQO_mg/L                368 non-null    object
#  15  CALIDAD_DQO             368 non-null    object
#  16  SST_mg/L                379 non-null    object
#  17  CALIDAD_SST             379 non-null    object
#  18  COLI_FEC_NMP_100mL      332 non-null    object
#  19  CALIDAD_COLI_FEC        332 non-null    object
#  20  E_COLI_NMP_100mL        103 non-null    object
#  21  CALIDAD_E_COLI          103 non-null    object
#  22  ENTEROC_NMP_100mL       10 non-null     object
#  23  CALIDAD_ENTEROC         10 non-null     object
#  24  OD_PORC                 60 non-null     object
#  25  CALIDAD_OD_PORC         60 non-null     object
#  26  OD_PORC_SUP             3 non-null      float64
#  27  CALIDAD_OD_PORC_SUP     3 non-null      object
#  28  OD_PORC_MED             0 non-null      float64
#  29  CALIDAD_OD_PORC_MED     0 non-null      float64
#  30  OD_PORC_FON             0 non-null      float64
#  31  CALIDAD_OD_PORC_FON     0 non-null      float64
#  32  TOX_D_48_UT             38 non-null     object
#  33  CALIDAD_TOX_D_48        38 non-null     object
#  34  TOX_V_15_UT             30 non-null     object
#  35  CALIDAD_TOX_V_15        30 non-null     object
#  36  TOX_D_48_SUP_UT         0 non-null      float64
#  37  CALIDAD TOX_D_48_SUP    0 non-null      float64
#  38  TOX_D_48_FON_UT         0 non-null      float64
#  39  CALIDAD_TOX_D_48_FON    0 non-null      float64
#  40  TOX_FIS_SUP_15_UT       13 non-null     float64
#  41  CALIDAD_TOX_FIS_SUP_15  13 non-null     object
#  42  TOX_FIS_FON_15_UT       0 non-null      float64
#  43  CALIDAD_TOX_FIS_FON_15  0 non-null      float64
#  44  SEMAFORO                450 non-null    object
#  45  CONTAMINANTES           327 non-null    object
# dtypes: float64(14), int64(1), object(31)
# memory usage: 161.8+ KB

# %%
df_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4775 entries, 0 to 4774
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLAVE                   4775 non-null   object
#  1   SITIO                   4774 non-null   object
#  2   ORGANISMO_DE_CUENCA     4775 non-null   object
#  3   ESTADO                  4775 non-null   object
#  4   MUNICIPIO               4775 non-null   object
#  5   CUENCA                  4773 non-null   object
#  6   CUERPO DE AGUA          4775 non-null   object
#  7   TIPO                    4775 non-null   object
#  8   SUBTIPO                 4773 non-null   object
#  9   LONGITUD                4775 non-null   float64
#  10  LATITUD                 4775 non-null   float64
#  11  PERIODO                 4775 non-null   object
#  12  DBO_mg/L                3688 non-null   object
#  13  CALIDAD_DBO             3688 non-null   object
#  14  DQO_mg/L                3696 non-null   object
#  15  CALIDAD_DQO             3696 non-null   object
#  16  SST_mg/L                4623 non-null   object
#  17  CALIDAD_SST             4623 non-null   object
#  18  COLI_FEC_NMP_100mL      4623 non-null   object
#  19  CALIDAD_COLI_FEC        4623 non-null   object
#  20  E_COLI_NMP_100mL        3516 non-null   object
#  21  CALIDAD_E_COLI          3516 non-null   object
#  22  ENTEROC_NMP_100mL       1216 non-null   object
#  23  CALIDAD_ENTEROC         1216 non-null   object
#  24  OD_PORC                 2487 non-null   object
#  25  CALIDAD_OD_PORC         2487 non-null   object
#  26  OD_PORC_SUP             2206 non-null   object
#  27  CALIDAD_OD_PORC_SUP     2206 non-null   object
#  28  OD_PORC_MED             1847 non-null   object
#  29  CALIDAD_OD_PORC_MED     1847 non-null   object
#  30  OD_PORC_FON             1863 non-null   object
#  31  CALIDAD_OD_PORC_FON     1863 non-null   object
#  32  TOX_D_48_UT             2447 non-null   object
#  33  CALIDAD_TOX_D_48        2447 non-null   object
#  34  TOX_V_15_UT             2437 non-null   object
#  35  CALIDAD_TOX_V_15        2437 non-null   object
#  36  TOX_D_48_SUP_UT         1107 non-null   object
#  37  CALIDAD TOX_D_48_SUP    1107 non-null   object
#  38  TOX_D_48_FON_UT         1045 non-null   object
#  39  CALIDAD_TOX_D_48_FON    1045 non-null   object
#  40  TOX_FIS_SUP_15_UT       2186 non-null   object
#  41  CALIDAD_TOX_FIS_SUP_15  2186 non-null   object
#  42  TOX_FIS_FON_15_UT       2132 non-null   object
#  43  CALIDAD_TOX_FIS_FON_15  2132 non-null   object
#  44  SEMAFORO                4775 non-null   object
#  45  CONTAMINANTES           2837 non-null   object
# dtypes: float64(2), object(44)
# memory usage: 1.7+ MB

# %%
df_A
# Out:
#              CLAVE                                             SITIO  \
# 0          DLAGU11     PRESA JOCOQUI 100M AGUAS ARRIBA DE LA CORTINA
# 1          DLAGU14               PRESA PRESIDENTE CALLES EMBARCADERO
# 2          DLAGU18                      PRESA 50 ANIVERSARIO CORTINA
# 3          DLAGU31                   PRESA EL NIAGARA CANAL DE RIEGO
# 4          DLAGU32  PRESA EL NIAGARA 100M AGUAS ARRIBA DE LA CORTINA
# ..             ...                                               ...
# 445    OCRBR5018M1                                          ESCOBEDO
# 446    OCRBR5021M1                                        TOPO CHICO
# 447    OCRBR5044M1                                          LA ARENA
# 448  SITIO NUEVO 1                                      RÍO ESLAVA 2
# 449  SITIO NUEVO 4                                         LA CAÑADA
#
#            ORGANISMO_DE_CUENCA            ESTADO                 MUNICIPIO  \
# 0      LERMA SANTIAGO PACIFICO    AGUASCALIENTES        SAN JOSÉ DE GRACIA
# 1      LERMA SANTIAGO PACIFICO    AGUASCALIENTES        SAN JOSÉ DE GRACIA
# 2      LERMA SANTIAGO PACIFICO    AGUASCALIENTES        SAN JOSÉ DE GRACIA
# 3      LERMA SANTIAGO PACIFICO    AGUASCALIENTES            AGUASCALIENTES
# 4      LERMA SANTIAGO PACIFICO    AGUASCALIENTES            AGUASCALIENTES
# ..                         ...               ...                       ...
# 445                  RIO BRAVO        NUEVO LEON          GENERAL ESCOBEDO
# 446                  RIO BRAVO        NUEVO LEON  SAN NICOLÁS DE LOS GARZA
# 447                  RIO BRAVO        NUEVO LEON                 PESQUERÍA
# 448  AGUAS DEL VALLE DE MEXICO  CIUDAD DE MEXICO    LA MAGDALENA CONTRERAS
# 449  AGUAS DEL VALLE DE MEXICO  CIUDAD DE MEXICO    LA MAGDALENA CONTRERAS
#
#                CUENCA           CUERPO DE AGUA               TIPO SUBTIPO  \
# 0       RÍO SAN PEDRO         PRESA EL JOCOQUI            LÉNTICO   PRESA
# 1        PRESA CALLES  PRESA PRESIDENTE CALLES  LÉNTICO (HUMEDAL)   PRESA
# 2        PRESA CALLES     PRESA 50 ANIVERSARIO            LÉNTICO   PRESA
# 3      PRESA AJOJUCAR         PRESA EL NIAGARA             LÓTICO   CANAL
# 4    PRESA EL NIÁGARA         PRESA EL NIAGARA  LÉNTICO (HUMEDAL)   PRESA
# ..                ...                      ...                ...     ...
# 445     RÍO PESQUERÍA            RIO PESQUERIA             LÓTICO     RÍO
# 446     RÍO PESQUERÍA        ARROYO TOPO CHICO             LÓTICO  ARROYO
# 447     RÍO PESQUERÍA            RIO PESQUERIA             LÓTICO     RÍO
# 448  CIUDAD DE MÉXICO               RÍO ESLAVA             LÓTICO     RÍO
# 449  CIUDAD DE MÉXICO            RÍO MAGDALENA             LÓTICO     RÍO
#
#        LONGITUD  ...  TOX_D_48_SUP_UT  CALIDAD TOX_D_48_SUP TOX_D_48_FON_UT  \
# 0   -102.357940  ...              NaN                   NaN             NaN
# 1   -102.426300  ...              NaN                   NaN             NaN
# 2   -102.465300  ...              NaN                   NaN             NaN
# 3   -102.373810  ...              NaN                   NaN             NaN
# 4   -102.370800  ...              NaN                   NaN             NaN
# ..          ...  ...              ...                   ...             ...
# 445 -100.277260  ...              NaN                   NaN             NaN
# 446 -100.255980  ...              NaN                   NaN             NaN
# 447 -100.008650  ...              NaN                   NaN             NaN
# 448  -99.237068  ...              NaN                   NaN             NaN
# 449  -99.251070  ...              NaN                   NaN             NaN
#
#     CALIDAD_TOX_D_48_FON TOX_FIS_SUP_15_UT CALIDAD_TOX_FIS_SUP_15  \
# 0                    NaN               NaN                    NaN
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
# ..                   ...               ...                    ...
# 445                  NaN               NaN                    NaN
# 446                  NaN               NaN                    NaN
# 447                  NaN               NaN                    NaN
# 448                  NaN               NaN                    NaN
# 449                  NaN               NaN                    NaN
#
#     TOX_FIS_FON_15_UT CALIDAD_TOX_FIS_FON_15  SEMAFORO CONTAMINANTES
# 0                 NaN                    NaN      Rojo          DQO,
# 1                 NaN                    NaN      Rojo          DQO,
# 2                 NaN                    NaN      Rojo          DQO,
# 3                 NaN                    NaN      Rojo          DQO,
# 4                 NaN                    NaN      Rojo          DQO,
# ..                ...                    ...       ...           ...
# 445               NaN                    NaN      Rojo      DQO,SST,
# 446               NaN                    NaN      Rojo      DQO,SST,
# 447               NaN                    NaN     Verde           NaN
# 448               NaN                    NaN  Amarillo    CF,E_COLI,
# 449               NaN                    NaN     Verde           NaN
#
# [450 rows x 46 columns]

# %%
df_SONORA=df_A[df_A['ESTADO']=="SONORA"]
df_SONORA
# Out:
#            CLAVE                        SITIO           ORGANISMO_DE_CUENCA  \
# 264  GCALNR00045  PRESA EL MOLINITO "EL VASO"                      NOROESTE
# 434    OCPBC4369       CANAL SANCHEZ MEJORADA  PENINSULA DE BAJA CALIFORNIA
# 435    OCPBC4370        CANAL SANCHEZ TABOADA  PENINSULA DE BAJA CALIFORNIA
#
#      ESTADO              MUNICIPIO        CUENCA          CUERPO DE AGUA  \
# 264  SONORA             HERMOSILLO  RIO SONORA 2              RÍO SONORA
# 434  SONORA  SAN LUIS RÍO COLORADO  RÍO COLORADO  CANAL SANCHEZ MEJORADA
# 435  SONORA  SAN LUIS RÍO COLORADO  RÍO COLORADO   CANAL SANCHEZ TABOADA
#
#         TIPO SUBTIPO    LONGITUD  ...  TOX_D_48_SUP_UT  CALIDAD TOX_D_48_SUP  \
# 264  LÉNTICO   PRESA -110.726794  ...              NaN                   NaN
# 434   LÓTICO   CANAL -114.790833  ...              NaN                   NaN
# 435   LÓTICO   CANAL -114.811944  ...              NaN                   NaN
#
#     TOX_D_48_FON_UT CALIDAD_TOX_D_48_FON TOX_FIS_SUP_15_UT  \
# 264             NaN                  NaN               NaN
# 434             NaN                  NaN               NaN
# 435             NaN                  NaN               NaN
#
#     CALIDAD_TOX_FIS_SUP_15 TOX_FIS_FON_15_UT CALIDAD_TOX_FIS_FON_15 SEMAFORO  \
# 264                    NaN               NaN                    NaN    Verde
# 434                    NaN               NaN                    NaN    Verde
# 435                    NaN               NaN                    NaN    Verde
#
#     CONTAMINANTES
# 264           NaN
# 434           NaN
# 435           NaN
#
# [3 rows x 46 columns]

# %%
df_A['ESTADO'].unique()
# Out:
# array(['AGUASCALIENTES', 'COAHUILA DE ZARAGOZA', 'COLIMA', 'DURANGO',
#        'ESTADO DE MEXICO', 'HIDALGO', 'MICHOACAN DE OCAMPO', 'NAYARIT',
#        'PUEBLA', 'QUINTANA ROO', 'SAN LUIS POTOSI', 'GUANAJUATO',
#        'TLAXCALA', 'ZACATECAS', 'JALISCO', 'SONORA', 'CIUDAD DE MEXICO',
#        'MORELOS', 'TAMAULIPAS', 'BAJA CALIFORNIA', 'NUEVO LEON'],
#       dtype=object)

# %%
df_SONORA_B=df_B[df_B['ESTADO']=="SONORA"]

# %%
df_SONORA_B
# Out:
#             CLAVE                                              SITIO  \
# 2243   GCAEH00043                                       AGUAS ARRIBA
# 2244   GCAEH00044                                        AGUAS ABAJO
# 2272  GCALNR00034                                              SITIO
# 2274  GCALNR00045                        PRESA EL MOLINITO "EL VASO"
# 2312      MET-003                            RÍO BACANUCHI LA TRAMPA
# ...           ...                                                ...
# 3964    OCPBC4361  SISTEMA DE HUMEDALES REMANENTES DEL DELTA DEL ...
# 3965    OCPBC4362  SISTEMA DE HUMEDALES REMANENTES DEL DELTA DEL ...
# 3966    OCPBC4369                             CANAL SANCHEZ MEJORADA
# 3967    OCPBC4370                              CANAL SANCHEZ TABOADA
# 4095    OCPNO4546  SISTEMA LAGUNAR AGIABAMPO-BACREHUIS-RIO FUERTE...
#
#                ORGANISMO_DE_CUENCA  ESTADO              MUNICIPIO  \
# 2243                      NOROESTE  SONORA                 YECORA
# 2244                      NOROESTE  SONORA                 YECORA
# 2272                      NOROESTE  SONORA                 YECORA
# 2274                      NOROESTE  SONORA             HERMOSILLO
# 2312                      NOROESTE  SONORA                 ARIZPE
# ...                            ...     ...                    ...
# 3964  PENINSULA DE BAJA CALIFORNIA  SONORA  SAN LUIS RIO COLORADO
# 3965  PENINSULA DE BAJA CALIFORNIA  SONORA  SAN LUIS RIO COLORADO
# 3966  PENINSULA DE BAJA CALIFORNIA  SONORA  SAN LUIS RIO COLORADO
# 3967  PENINSULA DE BAJA CALIFORNIA  SONORA  SAN LUIS RIO COLORADO
# 4095                      NOROESTE  SONORA             HUATABAMPO
#
#                              CUENCA  \
# 2243                    RÍO YAQUI 2
# 2244                    RÍO YAQUI 2
# 2272                     RÍO SONORA
# 2274                   RIO SONORA 2
# 2312                   RIO SONORA 1
# ...                             ...
# 3964                   RÍO COLORADO
# 3965                   RÍO COLORADO
# 3966                   RÍO COLORADO
# 3967                   RÍO COLORADO
# 4095  GRUPO DE CORRIENTES AGIABAMPO
#
#                                          CUERPO DE AGUA               TIPO  \
# 2243                                                  0             LÓTICO
# 2244                                                  0             LÓTICO
# 2272                                         RÍO SONORA             LÓTICO
# 2274                                         RÍO SONORA            LÉNTICO
# 2312                                      RIO BACANUCHI             LÓTICO
# ...                                                 ...                ...
# 3964                                         DREN RIITO   LÓTICO (HUMEDAL)
# 3965                                   DREN SANTA CLARA   LÓTICO (HUMEDAL)
# 3966                             CANAL SANCHEZ MEJORADA             LÓTICO
# 3967                              CANAL SANCHEZ TABOADA             LÓTICO
# 4095  SISTEMA LAGUNAR AGIABAMPO-BACREHUIS-RÍO FUERTE...  COSTERO (HUMEDAL)
#
#      SUBTIPO    LONGITUD  ...  TOX_D_48_SUP_UT CALIDAD TOX_D_48_SUP  \
# 2243     RÍO -109.181960  ...              NaN                  NaN
# 2244     RÍO -109.189110  ...              NaN                  NaN
# 2272     RÍO -109.182500  ...              NaN                  NaN
# 2274   PRESA -110.726794  ...              NaN                  NaN
# 2312     RÍO -110.220880  ...              NaN                  NaN
# ...      ...         ...  ...              ...                  ...
# 3964    DREN -114.956262  ...              NaN                  NaN
# 3965    DREN -114.929975  ...              NaN                  NaN
# 3966   CANAL -114.790833  ...              NaN                  NaN
# 3967   CANAL -114.811944  ...              NaN                  NaN
# 4095  LAGUNA -109.152250  ...              NaN                  NaN
#
#      TOX_D_48_FON_UT CALIDAD_TOX_D_48_FON TOX_FIS_SUP_15_UT  \
# 2243             NaN                  NaN               NaN
# 2244             NaN                  NaN               NaN
# 2272             NaN                  NaN               NaN
# 2274             NaN                  NaN               NaN
# 2312             NaN                  NaN               NaN
# ...              ...                  ...               ...
# 3964             NaN                  NaN               NaN
# 3965             NaN                  NaN               NaN
# 3966             NaN                  NaN               NaN
# 3967             NaN                  NaN               NaN
# 4095             NaN                  NaN                <1
#
#      CALIDAD_TOX_FIS_SUP_15 TOX_FIS_FON_15_UT CALIDAD_TOX_FIS_FON_15  \
# 2243                    NaN               NaN                    NaN
# 2244                    NaN               NaN                    NaN
# 2272                    NaN               NaN                    NaN
# 2274                    NaN               NaN                    NaN
# 2312                    NaN               NaN                    NaN
# ...                     ...               ...                    ...
# 3964                    NaN               NaN                    NaN
# 3965                    NaN               NaN                    NaN
# 3966                    NaN               NaN                    NaN
# 3967                    NaN               NaN                    NaN
# 4095              No Toxico                <1              No Toxico
#
#       SEMAFORO CONTAMINANTES
# 2243     Verde           NaN
# 2244     Verde           NaN
# 2272     Verde           NaN
# 2274     Verde           NaN
# 2312  Amarillo    CF,E_COLI,
# ...        ...           ...
# 3964     Verde           NaN
# 3965     Verde           NaN
# 3966     Verde           NaN
# 3967     Verde           NaN
# 4095     Verde           NaN
#
# [182 rows x 46 columns]

# %%
df_SONORA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 264 to 435
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLAVE                   3 non-null      object
#  1   SITIO                   3 non-null      object
#  2   ORGANISMO_DE_CUENCA     3 non-null      object
#  3   ESTADO                  3 non-null      object
#  4   MUNICIPIO               3 non-null      object
#  5   CUENCA                  3 non-null      object
#  6   CUERPO DE AGUA          3 non-null      object
#  7   TIPO                    3 non-null      object
#  8   SUBTIPO                 3 non-null      object
#  9   LONGITUD                3 non-null      float64
#  10  LATITUD                 3 non-null      float64
#  11  PERIODO                 3 non-null      int64
#  12  DBO_mg/L                2 non-null      object
#  13  CALIDAD_DBO             2 non-null      object
#  14  DQO_mg/L                1 non-null      object
#  15  CALIDAD_DQO             1 non-null      object
#  16  SST_mg/L                2 non-null      object
#  17  CALIDAD_SST             2 non-null      object
#  18  COLI_FEC_NMP_100mL      2 non-null      object
#  19  CALIDAD_COLI_FEC        2 non-null      object
#  20  E_COLI_NMP_100mL        0 non-null      object
#  21  CALIDAD_E_COLI          0 non-null      object
#  22  ENTEROC_NMP_100mL       0 non-null      object
#  23  CALIDAD_ENTEROC         0 non-null      object
#  24  OD_PORC                 2 non-null      object
#  25  CALIDAD_OD_PORC         2 non-null      object
#  26  OD_PORC_SUP             0 non-null      float64
#  27  CALIDAD_OD_PORC_SUP     0 non-null      object
#  28  OD_PORC_MED             0 non-null      float64
#  29  CALIDAD_OD_PORC_MED     0 non-null      float64
#  30  OD_PORC_FON             0 non-null      float64
#  31  CALIDAD_OD_PORC_FON     0 non-null      float64
#  32  TOX_D_48_UT             0 non-null      object
#  33  CALIDAD_TOX_D_48        0 non-null      object
#  34  TOX_V_15_UT             0 non-null      object
#  35  CALIDAD_TOX_V_15        0 non-null      object
#  36  TOX_D_48_SUP_UT         0 non-null      float64
#  37  CALIDAD TOX_D_48_SUP    0 non-null      float64
#  38  TOX_D_48_FON_UT         0 non-null      float64
#  39  CALIDAD_TOX_D_48_FON    0 non-null      float64
#  40  TOX_FIS_SUP_15_UT       0 non-null      float64
#  41  CALIDAD_TOX_FIS_SUP_15  0 non-null      object
#  42  TOX_FIS_FON_15_UT       0 non-null      float64
#  43  CALIDAD_TOX_FIS_FON_15  0 non-null      float64
#  44  SEMAFORO                3 non-null      object
#  45  CONTAMINANTES           0 non-null      object
# dtypes: float64(14), int64(1), object(31)
# memory usage: 1.1+ KB

# %%
df_SONORA_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 2243 to 4095
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CLAVE                   182 non-null    object
#  1   SITIO                   182 non-null    object
#  2   ORGANISMO_DE_CUENCA     182 non-null    object
#  3   ESTADO                  182 non-null    object
#  4   MUNICIPIO               182 non-null    object
#  5   CUENCA                  182 non-null    object
#  6   CUERPO DE AGUA          182 non-null    object
#  7   TIPO                    182 non-null    object
#  8   SUBTIPO                 182 non-null    object
#  9   LONGITUD                182 non-null    float64
#  10  LATITUD                 182 non-null    float64
#  11  PERIODO                 182 non-null    object
#  12  DBO_mg/L                118 non-null    object
#  13  CALIDAD_DBO             118 non-null    object
#  14  DQO_mg/L                120 non-null    object
#  15  CALIDAD_DQO             120 non-null    object
#  16  SST_mg/L                178 non-null    object
#  17  CALIDAD_SST             178 non-null    object
#  18  COLI_FEC_NMP_100mL      178 non-null    object
#  19  CALIDAD_COLI_FEC        178 non-null    object
#  20  E_COLI_NMP_100mL        121 non-null    object
#  21  CALIDAD_E_COLI          121 non-null    object
#  22  ENTEROC_NMP_100mL       67 non-null     object
#  23  CALIDAD_ENTEROC         67 non-null     object
#  24  OD_PORC                 97 non-null     object
#  25  CALIDAD_OD_PORC         97 non-null     object
#  26  OD_PORC_SUP             95 non-null     object
#  27  CALIDAD_OD_PORC_SUP     95 non-null     object
#  28  OD_PORC_MED             63 non-null     object
#  29  CALIDAD_OD_PORC_MED     63 non-null     object
#  30  OD_PORC_FON             62 non-null     object
#  31  CALIDAD_OD_PORC_FON     62 non-null     object
#  32  TOX_D_48_UT             92 non-null     object
#  33  CALIDAD_TOX_D_48        92 non-null     object
#  34  TOX_V_15_UT             96 non-null     object
#  35  CALIDAD_TOX_V_15        96 non-null     object
#  36  TOX_D_48_SUP_UT         28 non-null     object
#  37  CALIDAD TOX_D_48_SUP    28 non-null     object
#  38  TOX_D_48_FON_UT         25 non-null     object
#  39  CALIDAD_TOX_D_48_FON    25 non-null     object
#  40  TOX_FIS_SUP_15_UT       95 non-null     object
#  41  CALIDAD_TOX_FIS_SUP_15  95 non-null     object
#  42  TOX_FIS_FON_15_UT       95 non-null     object
#  43  CALIDAD_TOX_FIS_FON_15  95 non-null     object
#  44  SEMAFORO                182 non-null    object
#  45  CONTAMINANTES           95 non-null     object
# dtypes: float64(2), object(44)
# memory usage: 66.8+ KB

# %%
df_SONORA.columns
# Out:
# Index(['CLAVE', 'SITIO', 'ORGANISMO_DE_CUENCA', 'ESTADO', 'MUNICIPIO',
#        'CUENCA', 'CUERPO DE AGUA', 'TIPO', 'SUBTIPO', 'LONGITUD', 'LATITUD',
#        'PERIODO', 'DBO_mg/L', 'CALIDAD_DBO', 'DQO_mg/L', 'CALIDAD_DQO',
#        'SST_mg/L', 'CALIDAD_SST', 'COLI_FEC_NMP_100mL', 'CALIDAD_COLI_FEC',
#        'E_COLI_NMP_100mL', 'CALIDAD_E_COLI', 'ENTEROC_NMP_100mL',
#        'CALIDAD_ENTEROC', 'OD_PORC', 'CALIDAD_OD_PORC', 'OD_PORC_SUP',
#        'CALIDAD_OD_PORC_SUP', 'OD_PORC_MED', 'CALIDAD_OD_PORC_MED',
#        'OD_PORC_FON', 'CALIDAD_OD_PORC_FON', 'TOX_D_48_UT', 'CALIDAD_TOX_D_48',
#        'TOX_V_15_UT', 'CALIDAD_TOX_V_15', 'TOX_D_48_SUP_UT',
#        'CALIDAD TOX_D_48_SUP', 'TOX_D_48_FON_UT', 'CALIDAD_TOX_D_48_FON',
#        'TOX_FIS_SUP_15_UT', 'CALIDAD_TOX_FIS_SUP_15', 'TOX_FIS_FON_15_UT',
#        'CALIDAD_TOX_FIS_FON_15', 'SEMAFORO', 'CONTAMINANTES'],
#       dtype='object')

# %%
df_mgL_SONORA_A=df_SONORA[[
    'ESTADO',
    'PERIODO',
    'DBO_mg/L', 
    'DQO_mg/L',
    'SST_mg/L',
    'COLI_FEC_NMP_100mL',
    'E_COLI_NMP_100mL',
    'ENTEROC_NMP_100mL',
    'OD_PORC', 
    'OD_PORC_SUP', 
    'OD_PORC_MED', 
    'OD_PORC_FON',  
    'TOX_D_48_UT', 
    'TOX_V_15_UT',
    'TOX_D_48_SUP_UT',
    'TOX_D_48_FON_UT',
    'TOX_FIS_SUP_15_UT', 
    'TOX_FIS_FON_15_UT',
    'CALIDAD_TOX_FIS_FON_15', 
    'SEMAFORO', 
    'CONTAMINANTES'


]]

df_calidad_SONORA_A=df_SONORA[[
    'ESTADO',
    'PERIODO',
    'CALIDAD_DBO', 
    'CALIDAD_DQO',
    'CALIDAD_SST', 
    'CALIDAD_COLI_FEC',
    'CALIDAD_E_COLI',
    'CALIDAD_ENTEROC', 
    'CALIDAD_OD_PORC',
    'CALIDAD_OD_PORC_SUP', 
    'CALIDAD_OD_PORC_MED',
    'CALIDAD_OD_PORC_FON', 
    'CALIDAD_TOX_D_48',
    'CALIDAD_TOX_V_15',
    'CALIDAD TOX_D_48_SUP', 
    'CALIDAD_TOX_D_48_FON',
    'CALIDAD_TOX_FIS_SUP_15',
    'CALIDAD_TOX_FIS_FON_15', 
    'SEMAFORO', 
    'CONTAMINANTES'


]]

# %%
df_calidad_SONORA_A
# Out:
#      ESTADO  PERIODO CALIDAD_DBO CALIDAD_DQO    CALIDAD_SST CALIDAD_COLI_FEC  \
# 264  SONORA     2023         NaN   Aceptable            NaN              NaN
# 434  SONORA     2023   Excelente         NaN  Buena calidad        Aceptable
# 435  SONORA     2023   Excelente         NaN  Buena calidad        Excelente
#
#     CALIDAD_E_COLI CALIDAD_ENTEROC CALIDAD_OD_PORC CALIDAD_OD_PORC_SUP  \
# 264            NaN             NaN             NaN                 NaN
# 434            NaN             NaN       Excelente                 NaN
# 435            NaN             NaN       Excelente                 NaN
#
#      CALIDAD_OD_PORC_MED  CALIDAD_OD_PORC_FON CALIDAD_TOX_D_48  \
# 264                  NaN                  NaN              NaN
# 434                  NaN                  NaN              NaN
# 435                  NaN                  NaN              NaN
#
#     CALIDAD_TOX_V_15  CALIDAD TOX_D_48_SUP  CALIDAD_TOX_D_48_FON  \
# 264              NaN                   NaN                   NaN
# 434              NaN                   NaN                   NaN
# 435              NaN                   NaN                   NaN
#
#     CALIDAD_TOX_FIS_SUP_15  CALIDAD_TOX_FIS_FON_15 SEMAFORO CONTAMINANTES
# 264                    NaN                     NaN    Verde           NaN
# 434                    NaN                     NaN    Verde           NaN
# 435                    NaN                     NaN    Verde           NaN

# %%
df_mgL_SONORA_A
# Out:
#      ESTADO  PERIODO DBO_mg/L DQO_mg/L SST_mg/L COLI_FEC_NMP_100mL  \
# 264  SONORA     2023      NaN    20.06      NaN                NaN
# 434  SONORA     2023       <3      NaN       38                240
# 435  SONORA     2023       <3      NaN       47                 93
#
#     E_COLI_NMP_100mL ENTEROC_NMP_100mL OD_PORC  OD_PORC_SUP  ...  OD_PORC_FON  \
# 264              NaN               NaN     NaN          NaN  ...          NaN
# 434              NaN               NaN     102          NaN  ...          NaN
# 435              NaN               NaN     103          NaN  ...          NaN
#
#      TOX_D_48_UT TOX_V_15_UT TOX_D_48_SUP_UT  TOX_D_48_FON_UT  \
# 264          NaN         NaN             NaN              NaN
# 434          NaN         NaN             NaN              NaN
# 435          NaN         NaN             NaN              NaN
#
#      TOX_FIS_SUP_15_UT  TOX_FIS_FON_15_UT  CALIDAD_TOX_FIS_FON_15  SEMAFORO  \
# 264                NaN                NaN                     NaN     Verde
# 434                NaN                NaN                     NaN     Verde
# 435                NaN                NaN                     NaN     Verde
#
#     CONTAMINANTES
# 264           NaN
# 434           NaN
# 435           NaN
#
# [3 rows x 21 columns]

# %%
df_mgL_SONORA_B=df_SONORA_B[[
    'ESTADO',
    'PERIODO',
    'DBO_mg/L', 
    'DQO_mg/L',
    'SST_mg/L',
    'COLI_FEC_NMP_100mL',
    'E_COLI_NMP_100mL',
    'ENTEROC_NMP_100mL',
    'OD_PORC', 
    'OD_PORC_SUP', 
    'OD_PORC_MED', 
    'OD_PORC_FON',  
    'TOX_D_48_UT', 
    'TOX_V_15_UT',
    'TOX_D_48_SUP_UT',
    'TOX_D_48_FON_UT',
    'TOX_FIS_SUP_15_UT', 
    'TOX_FIS_FON_15_UT',
    'CALIDAD_TOX_FIS_FON_15', 
    'SEMAFORO', 
    'CONTAMINANTES'


]]

df_calidad_SONORA_B=df_SONORA_B[[
    'ESTADO',
    'PERIODO',
    'CALIDAD_DBO', 
    'CALIDAD_DQO',
    'CALIDAD_SST', 
    'CALIDAD_COLI_FEC',
    'CALIDAD_E_COLI',
    'CALIDAD_ENTEROC', 
    'CALIDAD_OD_PORC',
    'CALIDAD_OD_PORC_SUP', 
    'CALIDAD_OD_PORC_MED',
    'CALIDAD_OD_PORC_FON', 
    'CALIDAD_TOX_D_48',
    'CALIDAD_TOX_V_15',
    'CALIDAD TOX_D_48_SUP', 
    'CALIDAD_TOX_D_48_FON',
    'CALIDAD_TOX_FIS_SUP_15',
    'CALIDAD_TOX_FIS_FON_15', 
    'SEMAFORO', 
    'CONTAMINANTES'


]]

# %%
df_calidad_SONORA_B
# Out:
#       ESTADO    PERIODO    CALIDAD_DBO    CALIDAD_DQO    CALIDAD_SST  \
# 2243  SONORA  2012-2023            NaN            NaN            NaN
# 2244  SONORA  2012-2023            NaN            NaN            NaN
# 2272  SONORA  2012-2023            NaN            NaN            NaN
# 2274  SONORA  2012-2023            NaN      Aceptable            NaN
# 2312  SONORA  2012-2023      Excelente      Excelente      Aceptable
# ...      ...        ...            ...            ...            ...
# 3964  SONORA  2012-2023      Excelente  Buena calidad      Excelente
# 3965  SONORA  2012-2023  Buena calidad      Aceptable      Excelente
# 3966  SONORA  2012-2023      Excelente      Excelente  Buena calidad
# 3967  SONORA  2012-2023      Excelente  Buena calidad  Buena calidad
# 4095  SONORA  2012-2023            NaN            NaN  Buena calidad
#
#      CALIDAD_COLI_FEC           CALIDAD_E_COLI CALIDAD_ENTEROC  \
# 2243              NaN                      NaN             NaN
# 2244              NaN                      NaN             NaN
# 2272              NaN                      NaN             NaN
# 2274              NaN                      NaN             NaN
# 2312      Contaminada  Fuertemente contaminada             NaN
# ...               ...                      ...             ...
# 3964        Aceptable                Excelente             NaN
# 3965        Aceptable                Excelente             NaN
# 3966    Buena calidad                Excelente             NaN
# 3967        Excelente                Excelente             NaN
# 4095        Aceptable                      NaN       Excelente
#
#      CALIDAD_OD_PORC CALIDAD_OD_PORC_SUP CALIDAD_OD_PORC_MED  \
# 2243       Excelente                 NaN                 NaN
# 2244       Excelente                 NaN                 NaN
# 2272       Excelente                 NaN                 NaN
# 2274             NaN                 NaN                 NaN
# 2312       Excelente                 NaN                 NaN
# ...              ...                 ...                 ...
# 3964       Excelente                 NaN                 NaN
# 3965       Excelente                 NaN                 NaN
# 3966       Excelente                 NaN                 NaN
# 3967       Excelente                 NaN                 NaN
# 4095             NaN           Aceptable                 NaN
#
#      CALIDAD_OD_PORC_FON CALIDAD_TOX_D_48 CALIDAD_TOX_V_15  \
# 2243                 NaN              NaN              NaN
# 2244                 NaN              NaN              NaN
# 2272                 NaN              NaN              NaN
# 2274                 NaN              NaN              NaN
# 2312                 NaN        No Toxico        No Toxico
# ...                  ...              ...              ...
# 3964                 NaN        No Toxico        No Toxico
# 3965                 NaN        No Toxico        No Toxico
# 3966                 NaN        No Toxico        No Toxico
# 3967                 NaN        No Toxico        No Toxico
# 4095                 NaN              NaN              NaN
#
#      CALIDAD TOX_D_48_SUP CALIDAD_TOX_D_48_FON CALIDAD_TOX_FIS_SUP_15  \
# 2243                  NaN                  NaN                    NaN
# 2244                  NaN                  NaN                    NaN
# 2272                  NaN                  NaN                    NaN
# 2274                  NaN                  NaN                    NaN
# 2312                  NaN                  NaN                    NaN
# ...                   ...                  ...                    ...
# 3964                  NaN                  NaN                    NaN
# 3965                  NaN                  NaN                    NaN
# 3966                  NaN                  NaN                    NaN
# 3967                  NaN                  NaN                    NaN
# 4095                  NaN                  NaN              No Toxico
#
#      CALIDAD_TOX_FIS_FON_15  SEMAFORO CONTAMINANTES
# 2243                    NaN     Verde           NaN
# 2244                    NaN     Verde           NaN
# 2272                    NaN     Verde           NaN
# 2274                    NaN     Verde           NaN
# 2312                    NaN  Amarillo    CF,E_COLI,
# ...                     ...       ...           ...
# 3964                    NaN     Verde           NaN
# 3965                    NaN     Verde           NaN
# 3966                    NaN     Verde           NaN
# 3967                    NaN     Verde           NaN
# 4095              No Toxico     Verde           NaN
#
# [182 rows x 20 columns]

# %%
df_mgL_SONORA_B
# Out:
#       ESTADO    PERIODO DBO_mg/L DQO_mg/L SST_mg/L COLI_FEC_NMP_100mL  \
# 2243  SONORA  2012-2023      NaN      NaN      NaN                NaN
# 2244  SONORA  2012-2023      NaN      NaN      NaN                NaN
# 2272  SONORA  2012-2023      NaN      NaN      NaN                NaN
# 2274  SONORA  2012-2023      NaN    20.06      NaN                NaN
# 2312  SONORA  2012-2023       <3      <10     88.5               1658
# ...      ...        ...      ...      ...      ...                ...
# 3964  SONORA  2012-2023       <3       20      <25                230
# 3965  SONORA  2012-2023     3.28       27      <25                230
# 3966  SONORA  2012-2023       <3      <10   30.585                150
# 3967  SONORA  2012-2023       <3       14       27                 23
# 4095  SONORA  2012-2023      NaN      NaN     30.5              293.5
#
#      E_COLI_NMP_100mL ENTEROC_NMP_100mL OD_PORC OD_PORC_SUP  ... OD_PORC_FON  \
# 2243              NaN               NaN    99.3         NaN  ...         NaN
# 2244              NaN               NaN   100.7         NaN  ...         NaN
# 2272              NaN               NaN    99.4         NaN  ...         NaN
# 2274              NaN               NaN     NaN         NaN  ...         NaN
# 2312             1274               NaN      90         NaN  ...         NaN
# ...               ...               ...     ...         ...  ...         ...
# 3964               90               NaN    88.7         NaN  ...         NaN
# 3965               40               NaN    72.2         NaN  ...         NaN
# 3966               43               NaN    91.5         NaN  ...         NaN
# 3967               <3               NaN      94         NaN  ...         NaN
# 4095              NaN                10     NaN       120.1  ...         NaN
#
#      TOX_D_48_UT TOX_V_15_UT TOX_D_48_SUP_UT TOX_D_48_FON_UT  \
# 2243         NaN         NaN             NaN             NaN
# 2244         NaN         NaN             NaN             NaN
# 2272         NaN         NaN             NaN             NaN
# 2274         NaN         NaN             NaN             NaN
# 2312          <1          <1             NaN             NaN
# ...          ...         ...             ...             ...
# 3964          <1          <1             NaN             NaN
# 3965          <1          <1             NaN             NaN
# 3966          <1          <1             NaN             NaN
# 3967          <1          <1             NaN             NaN
# 4095         NaN         NaN             NaN             NaN
#
#      TOX_FIS_SUP_15_UT TOX_FIS_FON_15_UT CALIDAD_TOX_FIS_FON_15  SEMAFORO  \
# 2243               NaN               NaN                    NaN     Verde
# 2244               NaN               NaN                    NaN     Verde
# 2272               NaN               NaN                    NaN     Verde
# 2274               NaN               NaN                    NaN     Verde
# 2312               NaN               NaN                    NaN  Amarillo
# ...                ...               ...                    ...       ...
# 3964               NaN               NaN                    NaN     Verde
# 3965               NaN               NaN                    NaN     Verde
# 3966               NaN               NaN                    NaN     Verde
# 3967               NaN               NaN                    NaN     Verde
# 4095                <1                <1              No Toxico     Verde
#
#      CONTAMINANTES
# 2243           NaN
# 2244           NaN
# 2272           NaN
# 2274           NaN
# 2312    CF,E_COLI,
# ...            ...
# 3964           NaN
# 3965           NaN
# 3966           NaN
# 3967           NaN
# 4095           NaN
#
# [182 rows x 21 columns]

# %%
df_mgL_SONORA_A['DBO_mg/L']
# Out:
# 264    NaN
# 434     <3
# 435     <3
# Name: DBO_mg/L, dtype: object

# %%
df_mgL_SONORA_B['DBO_mg/L'].unique()
# Out:
# array([nan, '<3', 9.7, 8.2, 4.9, 7.9, 15.3, 7.8, 4.4, 3.19, 9.5, 5.78,
#        3.38, 27.884999999999998, 8.79, 6.07, 5.13, 9.37, 3.14,
#        4.2444500000000005, 3.06, 94.905, 346.155, 111.97, 199.44, 7.59,
#        3.66, 4, 8.25, 7.904999999999999, 12.445, 5.7, 5.105, 70.32, 4.06,
#        41.03, 5.305, 6.96, 9.98, 6.49, 3.685, 6.4, 3.2, 3.28],
#       dtype=object)

# %%
for column in df_mgL_SONORA_B.columns:
    print(column)
    print(df_mgL_SONORA_B[column].unique())
# Out:
# ESTADO
# ['SONORA']
# PERIODO
# ['2012-2023']
# DBO_mg/L
# [nan '<3' 9.7 8.2 4.9 7.9 15.3 7.8 4.4 3.19 9.5 5.78 3.38
#  27.884999999999998 8.79 6.07 5.13 9.37 3.14 4.2444500000000005 3.06
#  94.905 346.155 111.97 199.44 7.59 3.66 4 8.25 7.904999999999999 12.445
#  5.7 5.105 70.32 4.06 41.03 5.305 6.96 9.98 6.49 3.685 6.4 3.2 3.28]
# DQO_mg/L
# [nan 20.06 '<10' 344.74 29.26 16.72 24.13 26.62 40.92 17.64 18.91
#  20.258000000000003 12.992 49.15 13.38 33.04 12.365 13.57 11.93 10.97
#  21.74 11.87 11.445 15.96 38.78 30.817 10.565 17.7 19.5 14.49 15.05 20.894
#  20.9976 14.8296 12.1866 18.4722 15.5 13.895 17.69 17.994 18.39
#  91.36500000000001 17.028 16.7 18.450000000000003 22.67 17.48 15.31
#  67.9868 46.60705 59.828 47.355000000000004 31.75 216.82
#  48.790000000000006 13.66 517.79 1377.95 514 726.24 103.05 28.42 24.6
#  23.52 19.049999999999997 56.295 52.81 77.86 40.18 33.936 27.26 42.902
#  219.582 31.87 145.02 46.585 17.288 16.04 48.595 69.02 53.57 25.537 16.875
#  14.6658 12.5372 18.305 19.26 229.38 32.08 25.79 24.65 28.56 19.32 16
#  20.7698 62.57 72.76 54.32 10 16.73 16.76 25.91 14.07 20 27 14]
# SST_mg/L
# [nan 88.5 7583.3 '<25' 152 560.7 535.3 136 151.8 6014 6042 73.5 57.1
#  26.83335 26.335 66 153.66500000000002 25.15 29.5 31 46.4286 25.5 188.57
#  89.5909 28.5 114 124 67.5 43 41.5 264.4444 328.9 31.65 101.33500000000001
#  27.5 32 31.5 58.95495 657.5 500 220 200 51.166650000000004 39.6875 38.335
#  144.92000000000002 146.5 116.96000000000001 47.15 33.5 42 25 47 32.65
#  34.67 29.84 171.66500000000002 86 52 54 71.8 120 69.09 53 44.29 94
#  56.7742 74.91499999999999 29 27.072200000000002 35.75 313.75 40.585 79.5
#  111 42.7 33.9 142.1429 33 26.6667 50.305 51 27.3 30.585 27 30.5]
# COLI_FEC_NMP_100mL
# [nan 1658 24196 8164 2046 8300 6200 663 1500 120330 155310 52 41 1631
#  1211.5 '<3' 1956 5475 352.5 756 1467 2755 1856 3591 7765.5 2187 1122
#  2609.5 1296 2014 92.5 2247 2723 1153 2098 487 320.5 1376 92 166 165.5
#  149.5 153.5 3281.5 1663.5 3441 20 10 5.75 25.5 2486 1919.5 1973 20.5
#  233.5 1052 6867 14136 4413 14833.5 744 233 825 159.5 269 327 90330
#  2419600 241960 2430 2355.5 2497.5 1406 91.5 168 15 74.5 19863 30 6309.5
#  14403.5 6979 1686.5 1430 386.5 190.5 3255 571 256.5 172 174 46.5 80 3076
#  1092.5 529 9234 4352 141 63 287 275 110 187 223.5 842 2282 228 106 31
#  9564 2915.5 6.5 8772.5 9061.5 9 40 90 230 150 23 293.5]
# E_COLI_NMP_100mL
# [nan 1274 14136 272 269 620 1070 323 450 22470 '<3' 10 140 70.5 24196 31
#  504 30 52 63 148 166 212.5 196.5 110 85 41 98 5.75 20 62.5 637 57 89 410
#  160 1128.5 176.5 27598 1299700 105860 139.5 74 5172 865 6867 131 119
#  12247.5 170.5 1738 5475 660.5 68.5 3763.5 1931 1599.5 1570 61 1331 6131
#  30.5 4.25 3 90 40 43]
# ENTEROC_NMP_100mL
# [nan '<3' 20 10 51 61.5 69 1179 52 41 31 68.5 10970 193 5.75 72 6780 318
#  36 160 63 97.5]
# OD_PORC
# [99.3 100.7 99.4 nan 90 83.6 59 98.2 94 93.7 104.9 100.2 83.8 88.3 64.7
#  87.32499999999999 101.75 71.9 90.8 92 67.5 95.3 96.69999999999999 104.1
#  101.8 79.55000000000001 97 85.15 92.1 89.9 89.8 67.2 87.4 87.9
#  102.30000000000001 88.8 98.6 73.8 79.8 89.6 96 96.7 84.15 87.1 106.8
#  57.349999999999994 77.8 32.3 58.35 88.2 88 73.85 95.1 15.9 '<10' 23.5
#  28.7 54.9 96.4 48.87 95.69999999999999 75.5 28 91.7 55.9 113.2 106.3
#  93.75 83.85 58.9 90.19999999999999 40.9 85.9 79.6 85.80000000000001 87.35
#  95.9 111.55000000000001 85.7 100.1 97.6 92.4 10.9 96.75 102.7 88.7 72.2
#  91.5]
# OD_PORC_SUP
# [nan 113.6 119.7 97.9 86.5 102.7 91.1 91.25 96.3 97.2 102.1 101.65 105.3
#  103.5 104.4 102.6 105.4 110.15 109.8 103.8 95.25 99.1 88.8 126.8 118.45
#  87.9 112.69999999999999 93 99.55 25.1 68 100.7 100 101.05000000000001
#  105.19999999999999 105.7 101.44999999999999 101.7 102.9 103.4 101.8 99.9
#  118.4 112.75 114.75 97.05 93.15 107.05000000000001 108.1 109.4 97.35
#  108.4 114.3 '<10' 105.25 91.7 99.7 98.9 106.05000000000001 107 96.05 98.4
#  109.3 99.6 116.1 119.5 122.85 111.05 102.55 104 129.55 82.85 84.3 84.6
#  87.2 80.7 70.75 86.7 86.35 84.7 84.35 91.15 78.65 82.6 71.5
#  88.19999999999999 80.6 120.1]
# OD_PORC_MED
# [nan 55.6 64.3 78.85 75.25 49 54.7 54.9 69.85 62.9 84.9 82.85 78 86.1 88.5
#  104.75 105 103.3 101.7 54.6 103.6 86.3 89.61850000000001 50.3 112.7 74.85
#  90.9 97.5 113.95 101.4 99.3 103.5 93.25 100.4 97.4 90 86.5 56 95.7 94.4
#  102.19999999999999 96.05 104.1 111.55 105.15 '<10' 128.6 109.1 105.5
#  75.05 67.3 63.9 99.85 102 96.8 80.05 53.93 85.65 82.2 82.8 83.9 79.8 53.9]
# OD_PORC_FON
# [nan 55.6 38.5 56.05 71 37.8 53.3 48.4 51 45.5 84 67.9 49.75 75.2 79
#  104.75 101.95 102.55 90.5 54 99.65 81.8 86.5 62 116 94.05 129.4 99.5 99.3
#  92.9 93.3 94.75 97.8 73.5 74.9 40.2 91.1 104.15 96.1 100 107.05 105.05
#  '<10' 128.6 106.80000000000001 96.3 64.7 44.5 51.5 97.55 98.3 78.1 63.1
#  89.4 83.1 69.1 67 37.1 104.3 95.1]
# TOX_D_48_UT
# [nan '<1' 1250 7.369 1.27551020408163 1.04 2.21729490022173 10.44 4.749
#  2.53 1.63 9.75 32.041 8.18 4.99 7.03 1.05 1.56 1.554 3.36 1.62 3.37 2.18
#  1.8 1.0248001639680262]
# TOX_V_15_UT
# [nan '<1' 1.85185185185185 19.53 2.49 1.91975427145325 1.23 9.867 1.35
#  1.11358574610245 10.329938226969402 29.4985250737463 39.68 39.98 60.6061
#  9.472 1.98 5.46 1.5547 1.11 17.51 9.29 14.51 12.33 2.8 2.12]
# TOX_D_48_SUP_UT
# [nan '<1']
# TOX_D_48_FON_UT
# [nan '<1' 1.02]
# TOX_FIS_SUP_15_UT
# [nan '<1' 1.98412698412698 2.36 74.63 28.9017341040462 2.31 1.91]
# TOX_FIS_FON_15_UT
# [nan '<1' 48.0769 16.61 1.43]
# CALIDAD_TOX_FIS_FON_15
# [nan 'No Toxico' 'Toxicidad alta' 'Toxicidad moderada']
# SEMAFORO
# ['Verde' 'Amarillo' 'Rojo']
# CONTAMINANTES
# [nan 'CF,E_COLI,' 'DQO,SST,CF,E_COLI,' 'CF,' 'SST,CF,' 'SST,CF,E_COLI,'
#  'DQO,' 'TOX_L,' 'DQO,CF,E_COLI,TOX_L,' 'SST,' 'DQO,CF,' 'DQO,CF,ENT_FEC,'
#  'DQO,CF,E_COLI,ENT_FEC,OD%S,' 'DQO,CF,E_COLI,' 'DQO,E_COLI,' 'DQO,TOX_L,'
#  'DBO,DQO,SST,CF,E_COLI,OD%L,TOX_L,' 'DQO,CF,E_COLI,OD%L,TOX_L,' 'E_COLI,'
#  'DBO,DQO,CF,E_COLI,OD%L,TOX_L,' 'CF,E_COLI,TOX_L,'
#  'DBO,DQO,CF,E_COLI,TOX_L,' 'CF,ENT_FEC,OD%S,OD%M,OD%F,TOX_S,TOX_F,'
#  'SST,E_COLI,' 'DQO,CF,E_COLI,OD%L,']

# %%
import re
print(re.search(r"<\d{1,2}",df_mgL_SONORA_A['DBO_mg/L'][435]))
# Out:
# <re.Match object; span=(0, 2), match='<3'>

# %%
match=re.search(r"<\d{1,2}",df_mgL_SONORA_A['DBO_mg/L'][435])

# %%
match.group()
# Out:
# '<3'

# %%
variable=re.search(r"\d{1,2}",match.group())

# %%
float(variable.group())-0.1
# Out:
# 2.9

# %%
float(re.search(r"\d{1,2}",re.search(r"<\d{1,2}",df_mgL_SONORA_A['DBO_mg/L'][435]).group()).group())-0.1
# Out:
# 2.9

# %%
df_A
# Out:
#              CLAVE                                             SITIO  \
# 0          DLAGU11     PRESA JOCOQUI 100M AGUAS ARRIBA DE LA CORTINA
# 1          DLAGU14               PRESA PRESIDENTE CALLES EMBARCADERO
# 2          DLAGU18                      PRESA 50 ANIVERSARIO CORTINA
# 3          DLAGU31                   PRESA EL NIAGARA CANAL DE RIEGO
# 4          DLAGU32  PRESA EL NIAGARA 100M AGUAS ARRIBA DE LA CORTINA
# ..             ...                                               ...
# 445    OCRBR5018M1                                          ESCOBEDO
# 446    OCRBR5021M1                                        TOPO CHICO
# 447    OCRBR5044M1                                          LA ARENA
# 448  SITIO NUEVO 1                                      RÍO ESLAVA 2
# 449  SITIO NUEVO 4                                         LA CAÑADA
#
#            ORGANISMO_DE_CUENCA            ESTADO                 MUNICIPIO  \
# 0      LERMA SANTIAGO PACIFICO    AGUASCALIENTES        SAN JOSÉ DE GRACIA
# 1      LERMA SANTIAGO PACIFICO    AGUASCALIENTES        SAN JOSÉ DE GRACIA
# 2      LERMA SANTIAGO PACIFICO    AGUASCALIENTES        SAN JOSÉ DE GRACIA
# 3      LERMA SANTIAGO PACIFICO    AGUASCALIENTES            AGUASCALIENTES
# 4      LERMA SANTIAGO PACIFICO    AGUASCALIENTES            AGUASCALIENTES
# ..                         ...               ...                       ...
# 445                  RIO BRAVO        NUEVO LEON          GENERAL ESCOBEDO
# 446                  RIO BRAVO        NUEVO LEON  SAN NICOLÁS DE LOS GARZA
# 447                  RIO BRAVO        NUEVO LEON                 PESQUERÍA
# 448  AGUAS DEL VALLE DE MEXICO  CIUDAD DE MEXICO    LA MAGDALENA CONTRERAS
# 449  AGUAS DEL VALLE DE MEXICO  CIUDAD DE MEXICO    LA MAGDALENA CONTRERAS
#
#                CUENCA           CUERPO DE AGUA               TIPO SUBTIPO  \
# 0       RÍO SAN PEDRO         PRESA EL JOCOQUI            LÉNTICO   PRESA
# 1        PRESA CALLES  PRESA PRESIDENTE CALLES  LÉNTICO (HUMEDAL)   PRESA
# 2        PRESA CALLES     PRESA 50 ANIVERSARIO            LÉNTICO   PRESA
# 3      PRESA AJOJUCAR         PRESA EL NIAGARA             LÓTICO   CANAL
# 4    PRESA EL NIÁGARA         PRESA EL NIAGARA  LÉNTICO (HUMEDAL)   PRESA
# ..                ...                      ...                ...     ...
# 445     RÍO PESQUERÍA            RIO PESQUERIA             LÓTICO     RÍO
# 446     RÍO PESQUERÍA        ARROYO TOPO CHICO             LÓTICO  ARROYO
# 447     RÍO PESQUERÍA            RIO PESQUERIA             LÓTICO     RÍO
# 448  CIUDAD DE MÉXICO               RÍO ESLAVA             LÓTICO     RÍO
# 449  CIUDAD DE MÉXICO            RÍO MAGDALENA             LÓTICO     RÍO
#
#        LONGITUD  ...  TOX_D_48_SUP_UT  CALIDAD TOX_D_48_SUP TOX_D_48_FON_UT  \
# 0   -102.357940  ...              NaN                   NaN             NaN
# 1   -102.426300  ...              NaN                   NaN             NaN
# 2   -102.465300  ...              NaN                   NaN             NaN
# 3   -102.373810  ...              NaN                   NaN             NaN
# 4   -102.370800  ...              NaN                   NaN             NaN
# ..          ...  ...              ...                   ...             ...
# 445 -100.277260  ...              NaN                   NaN             NaN
# 446 -100.255980  ...              NaN                   NaN             NaN
# 447 -100.008650  ...              NaN                   NaN             NaN
# 448  -99.237068  ...              NaN                   NaN             NaN
# 449  -99.251070  ...              NaN                   NaN             NaN
#
#     CALIDAD_TOX_D_48_FON TOX_FIS_SUP_15_UT CALIDAD_TOX_FIS_SUP_15  \
# 0                    NaN               NaN                    NaN
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
# ..                   ...               ...                    ...
# 445                  NaN               NaN                    NaN
# 446                  NaN               NaN                    NaN
# 447                  NaN               NaN                    NaN
# 448                  NaN               NaN                    NaN
# 449                  NaN               NaN                    NaN
#
#     TOX_FIS_FON_15_UT CALIDAD_TOX_FIS_FON_15  SEMAFORO CONTAMINANTES
# 0                 NaN                    NaN      Rojo          DQO,
# 1                 NaN                    NaN      Rojo          DQO,
# 2                 NaN                    NaN      Rojo          DQO,
# 3                 NaN                    NaN      Rojo          DQO,
# 4                 NaN                    NaN      Rojo          DQO,
# ..                ...                    ...       ...           ...
# 445               NaN                    NaN      Rojo      DQO,SST,
# 446               NaN                    NaN      Rojo      DQO,SST,
# 447               NaN                    NaN     Verde           NaN
# 448               NaN                    NaN  Amarillo    CF,E_COLI,
# 449               NaN                    NaN     Verde           NaN
#
# [450 rows x 46 columns]

# %%
columnas_mediciones=[
    'DBO_mg/L', 
    'DQO_mg/L',
    'SST_mg/L',
    'COLI_FEC_NMP_100mL',
    'E_COLI_NMP_100mL',
    'ENTEROC_NMP_100mL',
    'OD_PORC', 
    'OD_PORC_SUP', 
    'OD_PORC_MED', 
    'OD_PORC_FON',  
    'TOX_D_48_UT', 
    'TOX_V_15_UT',
    'TOX_D_48_SUP_UT',
    'TOX_D_48_FON_UT',
    'TOX_FIS_SUP_15_UT', 
    'TOX_FIS_FON_15_UT',]
for columna in columnas_mediciones:
    for cantidad in df_A[columna]:
       
        if (type(cantidad)==type("hola")):
            expresion=re.search(r"<\d{1,2}",cantidad).group()
            numero_reemplazo=float(re.search(r"\d{1,2}",expresion).group())-0.1
            print(expresion,numero_reemplazo)
        
            df_A[columna]=df_A[columna].apply(lambda x: numero_reemplazo if x ==cantidad else x)
# Out:
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <10 9.9
# <10 9.9
# <10 9.9
# <10 9.9
# <10 9.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <25 24.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <3 2.9
# <10 9.9
# <10 9.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9
# <1 0.9

# %%
df_A=pd.read_excel(file_2023[0])

# %%
df_A=pd.read_excel(file_2023[0])
df_B=pd.read_excel(file_2012_to_2023[0])

# %%
for columna in columnas_mediciones:
    print(columna)
    print(df_A[columna].unique())
# Out:
# DBO_mg/L
# [   2.9          10.3           5.15                 nan    5.8
#     8.5955       52.666         3.425        19.4          13.46965
#     3.08         15.667        28.7555        8.522         7.33
#    25.533        31.744        17.211         4.33         31.67
#     5.07          4.59          7.1           4.76          5.92
#    42.1         114.67        113.33        337.            9.08
#   187.          101.2         105.7         110.3          17.45
#   115.7          22.9          20.35        184.67         32.7
#   101.         1204.          110.4          57.6          93.6
#    67.6         352.          135.          121.          565.
#   103.8          16.13        118.3         252.          359.
#    24.1          22.5          23.9          76.2          11.57
#    97.6         194.5          16.33         11.41          6.67
#     8.05          5.75          3.42          3.7         115.
#   535.8          52.975         5.25         53.82         34.2
#    37.35         43.35        376.2          92.4         355.2
#   113.           38.2          33.6         225.           89.4
#    55.68        354.6          87.3          29.7          56.4
#    68.6          80.1          16.3          28.6          64.8
#   122.25        109.8          87.          106.8         170.5875
#   229.2          93.75        199.7         154.35        214.875
#     8.34         45.9          31.57         47.2          68.9
#    77.7          70.6          20.4          22.2          21.18
#    34.54285714   71.55         35.95        123.1625      119.9625
#    38.9          21.075        24.96         60.325       993.
#   127.2         180.           76.2         118.2          59.55
#   174.75         45.36        102.           80.6          99.
#   176.625        36.7          41.625        81.6          88.475
#    44.025        37.6          35.1          20.3          52.35
#    50.64         12.48          5.46         27.7           3.21
#    18.3          20.7           3.8           6.54         15.02
#   512.           69.            4.9         216.          223.5
#     8.2           5.24          5.04          3.19          4.87
#    16.8           9.6           7.2         510.          120.
#   264.          276.          555.           24.           39.
#    39.6         300.          246.          450.           10.2
#   117.           29.8           4.08         15.84         37.
#     9.82          6.75          3.59         29.03          6.81
#    15.7          10.07          5.38          4.62         11.07
#    10.4           6.39          9.63          7.47         80.4
#    11.03          5.25        206.5          18.85         25.5
#    25.1          15.            3.38          9.87         55.4
#    97.            5.65          4.39          6.15          9.47
#     6.69          7.83          7.27         13.3           3.33
#     9.59         13.98          5.69         18.78          7.78
#    11.27          4.05         22.8          74.3          12.2
#    17.           45.            6.8           5.4           9.3
#    91.6           7.7          17.9          12.9          47.7
#    39.65         93.7          25.55          4.4          10.7
#     4.5           3.3           6.          130.           11.5
#     4.7          21.           54.4          30.           11.7
#    11.1          23.7          28.            6.5       ]
# DQO_mg/L
# [  60.       64.       62.       57.       82.       87.      330.
#    50.       66.       58.       23.7      23.4       9.9          nan
#    11.       27.2      21.       16.       12.666    12.       35.33
#   146.       19.33     24.      143.333    84.       30.33     13.67
#    10.67     44.333    30.       53.333    63.3      15.73     20.
#    35.       54.       72.61    296.04    189.63    131.11    169.17
#    53.66    200.76     64.4     475.65    237.84   3826.1     201.65
#   124.09    170.62    702.      210.74    241.47   1215.04    222.33
#    60.82    667.34     57.24     26.43    146.71    378.36     33.
#    38.       27.       51.       26.       19.       22.      238.
#   933.      123.5      26.1     100.5      52.       67.       75.
#   425.      111.      522.      140.       77.      296.       97.
#   317.      116.       70.      444.      108.      122.       41.
#    95.      123.       34.       40.       90.      249.      281.
#   274.      385.      285.      366.      278.      319.5      61.
#   417.       76.       84.5      78.5     163.5      43.       49.
#    63.      103.       73.      200.5     352.5      90.5    1814.
#   167.      346.      130.      223.      138.      201.      104.
#   286.      149.      187.      235.      129.      114.       45.
#    83.       28.      101.      298.9     239.       39.       37.
#   860.       53.      596.      750.      117.       44.       42.
#   121.       25.       15.       20.06     32.68     10.94    282.37
#    15.36    746.      236.84    536.51    536.84   1107.79     51.32
#    73.055    72.32    583.37    495.65    526.985   475.7     884.21
#    19.46    223.005   620.48     82.05     53.92     61.3      52.59
#   192.      322.91     52.36     43.64     34.91    113.45     55.14
#    26.98     16.42     12.9      25.14     25.62     16.99     76.46
#   110.45     67.97    410.26     48.29     90.26     54.625    64.44
#    58.63     73.85     33.34     21.98     16.39     43.45    129.24
#   127.44     16.71     32.79     24.51     33.42     21.17     50.14
#    25.45     45.18     27.11     27.1      35.06     26.3      24.94
#    63.12    109.92     11.23     17.26     98.      100.161   122.635
#    58.832    61.262    61.819   138.632    49.388    48.05     25.795
#   120.942   140.8005  421.813    70.8185   49.271    39.075    20.552
#    23.45     25.776    26.754   216.453    99.4885   51.8745   36.1865
#    79.      380.       42.5      33.4      58.9      78.       54.1
#    81.2      74.      386.      537.      206.       29.       36.    ]
# SST_mg/L
# [  24.9          27.           33.           47.5                  nan
#   592.          224.           28.           48.          104.
#   126.           30.           44.          292.           60.
#   164.          152.          100.           76.           32.
#    34.           27.27         37.5          56.66        120.
#   148.          720.          252.          145.          140.
#    78.18        226.67        215.          165.          370.
#   273.33         80.          180.           41.7          38.7
#    96.66666667  116.          186.66666667  113.33333333   70.
#    33.33333333   63.33333333   56.66666667   80.           95.
#    35.           50.           95.          135.           40.
#   290.          115.          300.          275.          110.
#   134.          120.          125.          106.5          43.33333333
#   175.           90.           43.33333333   65.83333333   93.33333333
#    46.66666667   53.33333333   66.66666667   40.           30.
#   125.          160.           75.          100.           55.
#    48.          135.          680.          140.          130.
#    93.33333333   70.           80.           45.           53.33333333
#   266.66666667   36.66666667  150.           50.           36.66666667
#    85.           58.          176.          276.           78.
#  2200.           70.          860.          490.          108.
#   110.          173.           82.          480.           39.
#   160.          181.          264.           96.          204.
#    81.          383.          460.          128.           42.
#    36.           38.           26.           97.           40.
#   186.           46.          390.         1444.           68.
#   158.          313.           50.           54.          170.
#    90.           41.           35.          160.32        290.48
#    67.         3023.08         92.         2350.         1994.12
#   274.          295.56         82.86        207.84         32.5
#    47.           66.         3643.         1427.          501.        ]
# COLI_FEC_NMP_100mL
# [           nan 9.00000000e+01 4.30000000e+02 3.00000000e+01
#  2.30000000e+04 4.30000000e+04 2.40000000e+05 1.10000000e+06
#  9.00000000e+03 7.00000000e+03 9.00000000e+00 4.30000000e+01
#  4.60000000e+03 4.30000000e+05 9.30000000e+01 4.00000000e+02
#  3.00000000e+02 4.60000000e+02 9.00000000e+04 2.90000000e+00
#  3.25000000e+02 1.00000000e+02 3.94000000e+03 6.00000000e+03
#  2.00000000e+01 6.05000000e+01 1.00000000e+01 1.73000000e+07
#  4.10000000e+02 4.50000000e+01 2.30000000e+01 2.40000000e+07
#  4.00000000e+06 2.10000000e+06 1.50000000e+04 1.10000000e+07
#  3.30000000e+07 4.60000000e+08 4.30000000e+07 2.30000000e+07
#  2.00000000e+04 1.50000000e+07 9.00000000e+05 4.30000000e+08
#  1.50000000e+08 2.30000000e+08 9.00000000e+07 4.00000000e+04
#  9.30000000e+07 2.10000000e+08 7.50000000e+07 1.50000000e+06
#  2.30000000e+05 4.00000000e+03 8.00000000e+04 1.20000000e+04
#  3.80000000e+01 1.60000000e+04 4.40000000e+03 3.30000000e+03
#  3.00000000e+05 1.50000000e+01 1.10000000e+03 1.30000000e+03
#  5.00000000e+02 9.00000000e+02 2.20000000e+03 9.80000000e+03
#  1.32000000e+07 7.02500000e+03 6.33333333e+00 2.04500000e+03
#  1.89000000e+03 3.90000000e+01 9.30000000e+02 2.00000000e+07
#  2.00000000e+05 5.10000000e+03 2.07000000e+06 5.00000000e+04
#  2.70000000e+04 4.20000000e+04 3.80000000e+02 1.75000000e+05
#  6.00000000e+05 2.70000000e+06 4.40000000e+07 8.10000000e+06
#  6.50000000e+06 4.10000000e+06 5.60000000e+06 1.46000000e+07
#  1.90000000e+06 1.09000000e+07 9.70000000e+06 1.00990000e+07
#  1.86000000e+06 6.00000000e+04 2.10000000e+05 9.30000000e+06
#  1.18000000e+07 1.07000000e+07 4.30000000e+06 6.70000000e+05
#  1.70000000e+06 3.30000000e+06 1.58000000e+07 1.81000000e+07
#  1.96000000e+07 1.30000000e+07 1.06000000e+07 1.66000000e+07
#  1.91000000e+07 8.80000000e+06 1.02000000e+07 1.85000000e+07
#  1.67000000e+06 3.70000000e+06 4.40000000e+06 6.20000000e+06
#  2.30000000e+06 1.72000000e+06 7.00000000e+06 8.00000000e+00
#  4.80000000e+01 4.20000000e+03 1.60000000e+01 6.40000000e+01
#  3.00000000e+00 1.12000000e+02 4.00000000e+01 6.00000000e+09
#  2.00000000e+02 3.40000000e+10 7.00000000e+04 4.60000000e+04
#  2.20000000e+04 3.40000000e+01 6.20000000e+01 1.40000000e+05
#  1.20000000e+02 2.56000000e+02 3.08800000e+05 5.56000000e+01
#  3.35000000e+04 1.80000000e+04 6.05000000e+03 8.25000000e+04
#  9.09000000e+07 2.33000000e+02 1.80000000e+01 1.37500000e+06
#  1.30320000e+06 2.40000000e+02 1.10000000e+04 1.50000000e+05
#  9.00000000e+06 2.30000000e+03 2.00000000e+03 9.30000000e+04
#  2.10000000e+07 2.40000000e+04 3.90000000e+04 4.60000000e+07
#  1.10000000e+08 1.00000000e+03 1.20000000e+07 2.10000000e+03
#  6.40000000e+06 1.50000000e+03 1.20000000e+06 1.55310000e+04
#  1.73290000e+04 4.60000000e+05 4.95000000e+07 9.30000000e+05
#  2.40000000e+06 6.40000000e+05 2.16200000e+04 9.30000000e+03
#  7.00000000e+00 7.50000000e+05 4.60000000e+06 6.70000000e+06
#  3.50000000e+06 2.67500000e+02 2.53000000e+05 2.53000000e+04
#  6.80000000e+01 1.50000000e+02 7.50000000e+01 7.76593100e+07
#  9.80000000e+02]
# E_COLI_NMP_100mL
# [         nan 2.900000e+00 9.000000e+03 2.400000e+05 4.600000e+05
#  7.000000e+03 4.000000e+06 9.000000e+05 7.000000e+06 4.300000e+07
#  1.500000e+08 9.000000e+06 9.300000e+07 2.300000e+07 4.410000e+07
#  2.000000e+02 1.200000e+01 2.000000e+05 3.900000e+03 2.000000e+03
#  4.000000e+03 7.000000e+04 1.500000e+05 4.000000e+02 3.000000e+02
#  4.300000e+04 7.500000e+05 9.300000e+06 2.100000e+02 2.400000e+04
#  4.000000e+00 9.300000e+02 6.400000e+02 1.500000e+04 7.500000e+07
#  4.000000e+05 2.300000e+05 7.500000e+02 3.900000e+05 4.611000e+03
#  4.884000e+03 9.000000e+04 1.200000e+04 1.300000e+06 8.000000e+05
#  3.600000e+06 3.000000e+05 3.900000e+07 5.000000e+02 1.400000e+03
#  2.000000e+06 4.000000e+01 9.000000e+01 1.100000e+07 4.600000e+06
#  3.500000e+06 2.400000e+06 4.600000e+03 2.400000e+07 2.675000e+02
#  4.600000e+04 1.430000e+04 2.586187e+07 1.730000e+02]
# ENTEROC_NMP_100mL
# [  nan   2.9 108.   85.  209.   10. ]
# OD_PORC
# [      nan 101.9485  103.71685  96.267    50.5      29.583   103.65
#  104.867    90.63335 182.567    97.       93.683   107.0495   89.53335
#   99.915   105.033    29.66     93.1     118.53    101.067    71.
#   45.2      92.233    52.5      29.1667    9.9     101.767   100.833
#   99.0667  100.933   101.533    98.633   119.6667   85.9     104.2
#  100.9      47.8      51.8      48.8      68.7      63.8      95.1
#   97.6      49.1      56.1     141.1      84.9     110.       44.5
#   77.5     102.      103.       81.       86.       88.      154.
#  100.      116.      123.     ]
# OD_PORC_SUP
# [ nan 87.3 89.3 88.5]
# OD_PORC_MED
# [nan]
# OD_PORC_FON
# [nan]
# TOX_D_48_UT
# [ nan 0.9  4.87 1.82 6.64 6.82 8.19]
# TOX_V_15_UT
# [   nan  4.781  7.559  0.9    1.546 14.12  19.19  23.56   2.367]
# TOX_D_48_SUP_UT
# [nan]
# TOX_D_48_FON_UT
# [nan]
# TOX_FIS_SUP_15_UT
# [  nan 4.529 1.658 1.609 1.599 1.482 1.364 1.853 1.926 2.096 1.788 1.797
#  1.184]
# TOX_FIS_FON_15_UT
# [nan]

# %%
contaminada_A=df_A[(df_A['SEMAFORO']!="Verde") & (df_A['ESTADO']=="SONORA")]
contaminada_B=df_B[(df_B['SEMAFORO']!="Verde") & (df_B['ESTADO']=="SONORA")]

# %%
contaminada_A
# Out:
# Empty DataFrame
# Columns: [CLAVE, SITIO, ORGANISMO_DE_CUENCA, ESTADO, MUNICIPIO, CUENCA, CUERPO DE AGUA, TIPO, SUBTIPO, LONGITUD, LATITUD, PERIODO, DBO_mg/L, CALIDAD_DBO, DQO_mg/L, CALIDAD_DQO, SST_mg/L, CALIDAD_SST, COLI_FEC_NMP_100mL, CALIDAD_COLI_FEC, E_COLI_NMP_100mL, CALIDAD_E_COLI, ENTEROC_NMP_100mL, CALIDAD_ENTEROC, OD_PORC, CALIDAD_OD_PORC, OD_PORC_SUP, CALIDAD_OD_PORC_SUP, OD_PORC_MED, CALIDAD_OD_PORC_MED, OD_PORC_FON, CALIDAD_OD_PORC_FON, TOX_D_48_UT, CALIDAD_TOX_D_48, TOX_V_15_UT, CALIDAD_TOX_V_15, TOX_D_48_SUP_UT, CALIDAD TOX_D_48_SUP, TOX_D_48_FON_UT, CALIDAD_TOX_D_48_FON, TOX_FIS_SUP_15_UT, CALIDAD_TOX_FIS_SUP_15, TOX_FIS_FON_15_UT, CALIDAD_TOX_FIS_FON_15, SEMAFORO, CONTAMINANTES]
# Index: []
#
# [0 rows x 46 columns]

# %%
contaminada_B
# Out:
#             CLAVE                                              SITIO  \
# 2312      MET-003                            RÍO BACANUCHI LA TRAMPA
# 2313     MET-011A                                  BAMORI RÍO SONORA
# 2314      MET-018                                  TAJO DE MANAMICHI
# 2315      MET-039                               BAVIÁCORA RÍO SONORA
# 2316      MET-040                              LA CAPILLA RÍO SONORA
# ...           ...                                                ...
# 3827  OCNOR4201W1  SISTEMA LAGUNAR AGIABAMPO-BACREHUIS-RIO FUERTE...
# 3828  OCNOR4202W1                        SISTEMA LAGUNAR AGIABAMPO 4
# 3839    OCNOR5315  LIGA MEXICO PANAMERICANA MEDICO EDUCACIONAL, A...
# 3840    OCNOR6513                                   BOQUILLA ORÉGANO
# 3841    OCNOR6515                                 HACIA EL ACUEDUCTO
#
#      ORGANISMO_DE_CUENCA  ESTADO   MUNICIPIO                         CUENCA  \
# 2312            NOROESTE  SONORA      ARIZPE                   RIO SONORA 1
# 2313            NOROESTE  SONORA      ARIZPE                   RIO SONORA 1
# 2314            NOROESTE  SONORA   BANAMICHI                   RIO SONORA 1
# 2315            NOROESTE  SONORA   BAVIACORA                   RIO SONORA 1
# 2316            NOROESTE  SONORA   BAVIACORA                   RIO SONORA 1
# ...                  ...     ...         ...                            ...
# 3827            NOROESTE  SONORA  HUATABAMPO  GRUPO DE CORRIENTES AGIABAMPO
# 3828            NOROESTE  SONORA  HUATABAMPO  GRUPO DE CORRIENTES AGIABAMPO
# 3839            NOROESTE  SONORA     NAVOJOA                     RÍO MAYO 3
# 3840            NOROESTE  SONORA  HERMOSILLO                   RÍO SONORA 2
# 3841            NOROESTE  SONORA  HERMOSILLO                   RÍO SONORA 2
#
#                                          CUERPO DE AGUA  \
# 2312                                      RIO BACANUCHI
# 2313                                         RIO SONORA
# 2314                                         RIO SONORA
# 2315                                         RIO SONORA
# 2316                                         RIO SONORA
# ...                                                 ...
# 3827  SISTEMA LAGUNAR AGIABAMPO-BACREHUIS-RÍO FUERTE...
# 3828                        SISTEMA LAGUNAR AGIABAMPO 4
# 3839                                      DREN AGRICOLA
# 3840                                  PRESA EL MOLINITO
# 3841                                         RIO SONORA
#
#                              TIPO SUBTIPO   LONGITUD  ...  TOX_D_48_SUP_UT  \
# 2312                       LÓTICO     RÍO -110.22088  ...              NaN
# 2313                       LÓTICO     RÍO -110.18746  ...              NaN
# 2314                       LÓTICO     RÍO -110.22364  ...              NaN
# 2315                       LÓTICO     RÍO -110.17292  ...              NaN
# 2316                       LÓTICO     RÍO -110.14605  ...              NaN
# ...                           ...     ...        ...  ...              ...
# 3827  LÉNTICO - COSTERO (HUMEDAL)  LAGUNA -109.12273  ...               <1
# 3828            LÉNTICO - COSTERO  LAGUNA -109.12356  ...              NaN
# 3839                       LÓTICO    DREN -109.53111  ...              NaN
# 3840                       LÓTICO   PRESA -110.70955  ...               <1
# 3841                       LÓTICO     RÍO -110.72855  ...              NaN
#
#      CALIDAD TOX_D_48_SUP TOX_D_48_FON_UT CALIDAD_TOX_D_48_FON  \
# 2312                  NaN             NaN                  NaN
# 2313                  NaN             NaN                  NaN
# 2314                  NaN             NaN                  NaN
# 2315                  NaN             NaN                  NaN
# 2316                  NaN             NaN                  NaN
# ...                   ...             ...                  ...
# 3827            No Toxico              <1            No Toxico
# 3828                  NaN             NaN                  NaN
# 3839                  NaN             NaN                  NaN
# 3840            No Toxico             NaN                  NaN
# 3841                  NaN             NaN                  NaN
#
#      TOX_FIS_SUP_15_UT CALIDAD_TOX_FIS_SUP_15 TOX_FIS_FON_15_UT  \
# 2312               NaN                    NaN               NaN
# 2313               NaN                    NaN               NaN
# 2314               NaN                    NaN               NaN
# 2315               NaN                    NaN               NaN
# 2316               NaN                    NaN               NaN
# ...                ...                    ...               ...
# 3827                <1              No Toxico                <1
# 3828                <1              No Toxico                <1
# 3839               NaN                    NaN               NaN
# 3840                <1              No Toxico                <1
# 3841               NaN                    NaN               NaN
#
#      CALIDAD_TOX_FIS_FON_15  SEMAFORO        CONTAMINANTES
# 2312                    NaN  Amarillo           CF,E_COLI,
# 2313                    NaN      Rojo   DQO,SST,CF,E_COLI,
# 2314                    NaN  Amarillo                  CF,
# 2315                    NaN  Amarillo              SST,CF,
# 2316                    NaN  Amarillo              SST,CF,
# ...                     ...       ...                  ...
# 3827              No Toxico      Rojo              DQO,CF,
# 3828              No Toxico  Amarillo                  CF,
# 3839                    NaN      Rojo  DQO,CF,E_COLI,OD%L,
# 3840              No Toxico      Rojo              DQO,CF,
# 3841                    NaN  Amarillo                  CF,
#
# [95 rows x 46 columns]

# %%
columnas_mediciones=[
    'DBO_mg/L', 
    'DQO_mg/L',
    'SST_mg/L',
    'COLI_FEC_NMP_100mL',
    'E_COLI_NMP_100mL',
    'ENTEROC_NMP_100mL',
    'OD_PORC', 
    'OD_PORC_SUP', 
    'OD_PORC_MED', 
    'OD_PORC_FON',  
    'TOX_D_48_UT', 
    'TOX_V_15_UT',
    'TOX_D_48_SUP_UT',
    'TOX_D_48_FON_UT',
    'TOX_FIS_SUP_15_UT', 
    'TOX_FIS_FON_15_UT',]

concentraciones={}

for cuerpo in contaminada_B['CUERPO DE AGUA']:
    indeces=contaminada_B[contaminada_B['CUERPO DE AGUA']==cuerpo].index.tolist()
    agente={}
    for columna in columnas_mediciones:
        
        concentracion_acum=0
        for index in indeces:
            cantidad=contaminada_B[columna][index]
            if (type(cantidad)==type("hola")):
                expresion=re.search(r"<\d{1,2}",cantidad).group()
                numero_reemplazo=float(re.search(r"\d{1,2}",expresion).group())-0.1
                concentracion_acum+=numero_reemplazo
            elif pd.isnull(cantidad)==False:
                concentracion_acum+=cantidad
            else:
                continue

        agente[columna]=concentracion_acum/len(indeces)
    concentraciones[cuerpo]=agente
        
print(concentraciones)

# %%
print(concentraciones)
# Out:
# {'RIO BACANUCHI': {'DBO_mg/L': 2.9, 'DQO_mg/L': 9.9, 'SST_mg/L': 56.7, 'COLI_FEC_NMP_100mL': 1579.0, 'E_COLI_NMP_100mL': 692.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 91.05, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'RIO SONORA': {'DBO_mg/L': 5.225789473684213, 'DQO_mg/L': 32.44684210526315, 'SST_mg/L': 1129.9262289473693, 'COLI_FEC_NMP_100mL': 18861.126315789475, 'E_COLI_NMP_100mL': 3311.6526315789474, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 90.03815789473686, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 66.64947368421056, 'TOX_V_15_UT': 2.001663480173952, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'PRESA EL MOLINITO': {'DBO_mg/L': 4.693333333333333, 'DQO_mg/L': 44.67333333333334, 'SST_mg/L': 49.568333333333335, 'COLI_FEC_NMP_100mL': 3612.8333333333335, 'E_COLI_NMP_100mL': 43.800000000000004, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 29.133333333333336, 'OD_PORC_SUP': 68.25, 'OD_PORC_MED': 18.533333333333335, 'OD_PORC_FON': 40.86666666666667, 'TOX_D_48_UT': 0.3, 'TOX_V_15_UT': 0.3, 'TOX_D_48_SUP_UT': 0.6, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.6, 'TOX_FIS_FON_15_UT': 0.6}, 'RIO AGUA PRIETA': {'DBO_mg/L': 4.34, 'DQO_mg/L': 25.975, 'SST_mg/L': 45.45, 'COLI_FEC_NMP_100mL': 3553.0, 'E_COLI_NMP_100mL': 322.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 66.1, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'ARROYO EL BARRILITO': {'DBO_mg/L': 9.5, 'DQO_mg/L': 49.15, 'SST_mg/L': 26.335, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 24196.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 71.9, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 7.369, 'TOX_V_15_UT': 2.49, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'RIO YAQUI': {'DBO_mg/L': 3.075416666666666, 'DQO_mg/L': 20.240883333333333, 'SST_mg/L': 43.43125, 'COLI_FEC_NMP_100mL': 4722.208333333333, 'E_COLI_NMP_100mL': 1206.5833333333333, 'ENTEROC_NMP_100mL': 0.24166666666666667, 'OD_PORC': 90.14166666666667, 'OD_PORC_SUP': 8.325000000000001, 'OD_PORC_MED': 8.116666666666667, 'OD_PORC_FON': 8.15, 'TOX_D_48_UT': 0.9347745750184777, 'TOX_V_15_UT': 0.9000000000000002, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.075, 'TOX_FIS_FON_15_UT': 0.075}, 'RIO MAGDALENA': {'DBO_mg/L': 2.9, 'DQO_mg/L': 11.445, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 2609.5, 'E_COLI_NMP_100mL': 110.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 89.8, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'RIO SAHUARIPA': {'DBO_mg/L': 2.9, 'DQO_mg/L': 14.279499999999999, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 1955.25, 'E_COLI_NMP_100mL': 57.25, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 99.5, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'RIO MATAPE': {'DBO_mg/L': 2.9, 'DQO_mg/L': 17.7, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 2723.0, 'E_COLI_NMP_100mL': 63.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 90.8, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}, 'RIO MOCTEZUMA': {'DBO_mg/L': 2.9, 'DQO_mg/L': 9.9, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 3441.0, 'E_COLI_NMP_100mL': 637.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 92.0, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX ...

# %%
for item in concentraciones:
    print(item)
    print(concentraciones[item])
# Out:
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 9.9, 'SST_mg/L': 56.7, 'COLI_FEC_NMP_100mL': 1579.0, 'E_COLI_NMP_100mL': 692.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 91.05, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 5.225789473684213, 'DQO_mg/L': 32.44684210526315, 'SST_mg/L': 1129.9262289473693, 'COLI_FEC_NMP_100mL': 18861.126315789475, 'E_COLI_NMP_100mL': 3311.6526315789474, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 90.03815789473686, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 66.64947368421056, 'TOX_V_15_UT': 2.001663480173952, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 4.693333333333333, 'DQO_mg/L': 44.67333333333334, 'SST_mg/L': 49.568333333333335, 'COLI_FEC_NMP_100mL': 3612.8333333333335, 'E_COLI_NMP_100mL': 43.800000000000004, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 29.133333333333336, 'OD_PORC_SUP': 68.25, 'OD_PORC_MED': 18.533333333333335, 'OD_PORC_FON': 40.86666666666667, 'TOX_D_48_UT': 0.3, 'TOX_V_15_UT': 0.3, 'TOX_D_48_SUP_UT': 0.6, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.6, 'TOX_FIS_FON_15_UT': 0.6}
# {'DBO_mg/L': 4.34, 'DQO_mg/L': 25.975, 'SST_mg/L': 45.45, 'COLI_FEC_NMP_100mL': 3553.0, 'E_COLI_NMP_100mL': 322.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 66.1, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 9.5, 'DQO_mg/L': 49.15, 'SST_mg/L': 26.335, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 24196.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 71.9, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 7.369, 'TOX_V_15_UT': 2.49, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 3.075416666666666, 'DQO_mg/L': 20.240883333333333, 'SST_mg/L': 43.43125, 'COLI_FEC_NMP_100mL': 4722.208333333333, 'E_COLI_NMP_100mL': 1206.5833333333333, 'ENTEROC_NMP_100mL': 0.24166666666666667, 'OD_PORC': 90.14166666666667, 'OD_PORC_SUP': 8.325000000000001, 'OD_PORC_MED': 8.116666666666667, 'OD_PORC_FON': 8.15, 'TOX_D_48_UT': 0.9347745750184777, 'TOX_V_15_UT': 0.9000000000000002, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.075, 'TOX_FIS_FON_15_UT': 0.075}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 11.445, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 2609.5, 'E_COLI_NMP_100mL': 110.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 89.8, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 14.279499999999999, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 1955.25, 'E_COLI_NMP_100mL': 57.25, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 99.5, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 17.7, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 2723.0, 'E_COLI_NMP_100mL': 63.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 90.8, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 9.9, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 3441.0, 'E_COLI_NMP_100mL': 637.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 92.0, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 27.884999999999998, 'DQO_mg/L': 91.36500000000001, 'SST_mg/L': 46.4286, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 24196.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 84.15, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 10.44, 'TOX_V_15_UT': 9.867, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 14.230000000000002, 'SST_mg/L': 24.899999999999995, 'COLI_FEC_NMP_100mL': 2126.1666666666665, 'E_COLI_NMP_100mL': 32.333333333333336, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 98.55, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 188.57, 'COLI_FEC_NMP_100mL': 20.5, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 20.0, 'OD_PORC': 0.0, 'OD_PORC_SUP': 110.15, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 33.95, 'COLI_FEC_NMP_100mL': 2732.5, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 31.0, 'OD_PORC': 0.0, 'OD_PORC_SUP': 102.19999999999999, 'OD_PORC_MED': 82.23425, 'OD_PORC_FON': 74.25, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 9.101666666666667, 'DQO_mg/L': 64.15128333333332, 'SST_mg/L': 79.63333333333334, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 2455.3333333333335, 'ENTEROC_NMP_100mL': 410.0, 'OD_PORC': 63.68333333333333, 'OD_PORC_SUP': 58.9, 'OD_PORC_MED': 37.56666666666667, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 1.12, 'TOX_V_15_UT': 1.12, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.6, 'TOX_FIS_FON_15_UT': 0.6}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 114.0, 'COLI_FEC_NMP_100mL': 6867.0, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 61.5, 'OD_PORC': 0.0, 'OD_PORC_SUP': 126.8, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 124.0, 'COLI_FEC_NMP_100mL': 14136.0, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 69.0, 'OD_PORC': 0.0, 'OD_PORC_SUP': 118.45, 'OD_PORC_MED': 50.3, 'OD_PORC_FON': 51.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 152.9722, 'COLI_FEC_NMP_100mL': 7788.75, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 36.0, 'OD_PORC': 0.0, 'OD_PORC_SUP': 102.85, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 1.44206349206349, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 328.9, 'COLI_FEC_NMP_100mL': 233.0, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 68.5, 'OD_PORC': 0.0, 'OD_PORC_SUP': 99.55, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 5.13, 'DQO_mg/L': 59.828, 'SST_mg/L': 31.65, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 24196.0, 'ENTEROC_NMP_100mL': 10970.0, 'OD_PORC': 32.3, 'OD_PORC_SUP': 25.1, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 4.749, 'TOX_V_15_UT': 1.11358574610245, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 113.998, 'DQO_mg/L': 512.0290000000001, 'SST_mg/L': 306.00033, 'COLI_FEC_NMP_100mL': 560056.4, 'E_COLI_NMP_100mL': 296310.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 32.510000000000005, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 11.9062, 'TOX_V_15_UT': 23.906105014749258, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 3.736249999999999, 'DQO_mg/L': 50.5756, 'SST_mg/L': 26.112500000000004, 'COLI_FEC_NMP_100mL': 7414.3125, 'E_COLI_NMP_100mL': 825.4375, 'ENTEROC_NMP_100mL': 25.375, 'OD_PORC': 77.33375, 'OD_PORC_SUP': 21.0875, 'OD_PORC_MED': 11.3625, 'OD_PORC_FON': 14.5, 'TOX_D_48_UT': 1.01, 'TOX_V_15_UT': 1.6050000000000002, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.225, 'TOX_FIS_FON_15_UT': 0.225}
# {'DBO_mg/L': 4.2444500000000005, 'DQO_mg/L': 48.790000000000006, 'SST_mg/L': 58.95495, 'COLI_FEC_NMP_100mL': 269.0, 'E_COLI_NMP_100mL': 176.5, 'ENTEROC_NMP_100mL': 5.75, 'OD_PORC': 73.85, 'OD_PORC_SUP': 101.05000000000001, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 10.329938226969402, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 199.44, 'DQO_mg/L': 726.24, 'SST_mg/L': 200.0, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 24196.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 28.7, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 4.99, 'TOX_V_15_UT': 60.6061, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 3.66, 'DQO_mg/L': 28.42, 'SST_mg/L': 39.6875, 'COLI_FEC_NMP_100mL': 2430.0, 'E_COLI_NMP_100mL': 139.5, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 96.4, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 23.52, 'SST_mg/L': 38.335, 'COLI_FEC_NMP_100mL': 2497.5, 'E_COLI_NMP_100mL': 74.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 95.69999999999999, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 7.904999999999999, 'DQO_mg/L': 52.81, 'SST_mg/L': 144.92000000000002, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 865.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 91.7, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 1.5547, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 40.18, 'SST_mg/L': 116.96000000000001, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 131.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 113.2, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 1.554, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 37.8125, 'DQO_mg/L': 133.0835, 'SST_mg/L': 55.45, 'COLI_FEC_NMP_100mL': 15587.5, 'E_COLI_NMP_100mL': 12428.25, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 53.150000000000006, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 2.13, 'TOX_V_15_UT': 9.205, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 22.545, 'DQO_mg/L': 88.44500000000001, 'SST_mg/L': 53.0, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 14835.5, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 65.55, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 2.495, 'TOX_V_15_UT': 11.899999999999999, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 17.288, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 1686.5, 'E_COLI_NMP_100mL': 68.5, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 96.0, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 6.96, 'DQO_mg/L': 48.595, 'SST_mg/L': 71.8, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 3763.5, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 79.6, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 12.33, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 8.235, 'DQO_mg/L': 61.295, 'SST_mg/L': 94.545, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 1765.25, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 86.575, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 1.9900000000000002, 'TOX_V_15_UT': 2.46, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 41.25, 'COLI_FEC_NMP_100mL': 2084.25, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 3549.0, 'OD_PORC': 0.0, 'OD_PORC_SUP': 9.9, 'OD_PORC_MED': 9.9, 'OD_PORC_FON': 9.9, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 51.7658670520231, 'TOX_FIS_FON_15_UT': 32.343450000000004}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 114.69, 'SST_mg/L': 196.625, 'COLI_FEC_NMP_100mL': 2440.5, 'E_COLI_NMP_100mL': 1450.5, 'ENTEROC_NMP_100mL': 18.0, 'OD_PORC': 55.775000000000006, 'OD_PORC_SUP': 102.475, 'OD_PORC_MED': 64.3, 'OD_PORC_FON': 64.3, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.45, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 2.9, 'DQO_mg/L': 19.26, 'SST_mg/L': 40.585, 'COLI_FEC_NMP_100mL': 9234.0, 'E_COLI_NMP_100mL': 61.0, 'ENTEROC_NMP_100mL': 160.0, 'OD_PORC': 92.0, 'OD_PORC_SUP': 91.7, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.9, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 6.4, 'DQO_mg/L': 62.57, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 9564.0, 'E_COLI_NMP_100mL': 10.0, 'ENTEROC_NMP_100mL': 97.5, 'OD_PORC': 0.0, 'OD_PORC_SUP': 108.1, 'OD_PORC_MED': 96.8, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.9, 'TOX_D_48_FON_UT': 0.9, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 0.0, 'DQO_mg/L': 0.0, 'SST_mg/L': 142.1429, 'COLI_FEC_NMP_100mL': 2915.5, 'E_COLI_NMP_100mL': 0.0, 'ENTEROC_NMP_100mL': 41.0, 'OD_PORC': 0.0, 'OD_PORC_SUP': 129.55, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 0.0, 'TOX_V_15_UT': 0.0, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.9, 'TOX_FIS_FON_15_UT': 0.9}
# {'DBO_mg/L': 3.2, 'DQO_mg/L': 72.76, 'SST_mg/L': 24.9, 'COLI_FEC_NMP_100mL': 24196.0, 'E_COLI_NMP_100mL': 6131.0, 'ENTEROC_NMP_100mL': 0.0, 'OD_PORC': 10.9, 'OD_PORC_SUP': 0.0, 'OD_PORC_MED': 0.0, 'OD_PORC_FON': 0.0, 'TOX_D_48_UT': 1.0248001639680262, 'TOX_V_15_UT': 0.9, 'TOX_D_48_SUP_UT': 0.0, 'TOX_D_48_FON_UT': 0.0, 'TOX_FIS_SUP_15_UT': 0.0, 'TOX_FIS_FON_15_UT': 0.0}
